# %% [markdown]
# # Getting started with dataset

# %% [markdown]
# Using pandas dataframes to load the dataset

# %%
import pandas as pd

# %% [markdown]
# Download the dataset from URL and read it as a tab separated file in a pandas dataframe.
# The dataset is of web queries with ten probable passages that could be answers to the query.
# But only one of those passages is the correct answer.

# %%
# location of the dataset in filesystem
dataset_location = 'C:\ds\msaic\Starting Kit\\answers\\data.tsv'

dataset = pd.read_csv(dataset_location, sep='\t', names = ["id","query","passage","label","index"])

# %% [markdown]
# Checking out the size of dataset reveals...

# %%
dataset.shape
# Out:
# (5241880, 5)

# %% [markdown]
# ... it's huge.
#
# 5+ million rows.
#
# Since each query has exactly 10 passages,
# this would mean that it has 5241880/10 = 524188 queries.
#
# <img src="https://media1.tenor.com/images/077a38dbc8acdf55ef54ba3fd909bbb6/tenor.gif?itemid=10323653" align="left" style="height:25%; width: 25%"></img>

# %% [markdown]
# Let's see how a query looks

# %%
# printing the first 10 rows
dataset[0:10]
# Out:
#    id                     query  \
# 0   0  . what is a corporation?
# 1   0  . what is a corporation?
# 2   0  . what is a corporation?
# 3   0  . what is a corporation?
# 4   0  . what is a corporation?
# 5   0  . what is a corporation?
# 6   0  . what is a corporation?
# 7   0  . what is a corporation?
# 8   0  . what is a corporation?
# 9   0  . what is a corporation?
#
#                                              passage  label  index
# 0  A company is incorporated in a specific nation...      0      0
# 1  Today, there is a growing community of more th...      0      1
# 2  Corporation definition, an association of indi...      0      2
# 3  Examples of corporation in a Sentence. 1  He w...      0      3
# 4  1: a government-owned corporation (as a utilit...      0      4
# 5  McDonald's Corporation is one of the most reco...      1      5
# 6  Corporations are owned by their stockholders (...      0      6
# 7  An Association is an organized group of people...      0      7
# 8  B Corp certification shines a light on the com...      0      8
# 9  LLCs offer greater flexibility when it comes t...      0      9

# %% [markdown]
# Every row of the dataset has five columns:
# #### 1. Query ID
# This is an ID presumably given to each query by the data curators. It would also help them in evaluating the results in contests.
# #### 2. Query
# This is the actual query that users have entered in search engines.
# #### 3. Passage
# The passage is the probable webpage that is the best match for answering the query.
# #### 4. Label
# Label indicates if the passage is the right answer or not. 0 for wrong and 1 for right.
# #### 5. Index
# This just denotes the index of the passage. It will range from 0 to 9 for each query.

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# We can notice how the query above was followed by a random period (.)
#
# Just to ensure this doesn't trouble us while parsing, we'll strip unnecessary characters from the front and back of the query.

# %%
dataset['query'] = dataset['query'].str.strip(".,?! ")
dataset[0:10]
# Out:
#    id                  query  \
# 0   0  what is a corporation
# 1   0  what is a corporation
# 2   0  what is a corporation
# 3   0  what is a corporation
# 4   0  what is a corporation
# 5   0  what is a corporation
# 6   0  what is a corporation
# 7   0  what is a corporation
# 8   0  what is a corporation
# 9   0  what is a corporation
#
#                                              passage  label  index
# 0  A company is incorporated in a specific nation...      0      0
# 1  Today, there is a growing community of more th...      0      1
# 2  Corporation definition, an association of indi...      0      2
# 3  Examples of corporation in a Sentence. 1  He w...      0      3
# 4  1: a government-owned corporation (as a utilit...      0      4
# 5  McDonald's Corporation is one of the most reco...      1      5
# 6  Corporations are owned by their stockholders (...      0      6
# 7  An Association is an organized group of people...      0      7
# 8  B Corp certification shines a light on the com...      0      8
# 9  LLCs offer greater flexibility when it comes t...      0      9

# %% [markdown]
# # Dividing the dataset

# %% [markdown]
# It is not wise to run any algorithm over the complete dataset at first.
#
# Let's work on only 100,000 rows and see how good is the learning.
#
# For that it must be first divided into three parts(60-20-20):
#
# - Training set (60,000 rows)
#
# - Cross validation set (20,000 rows)
#
# - Test set (20,000 rows)

# %%
training_set = dataset[0:60000]
cv_set = dataset[60001:80000]
test_set = dataset[80000:100000]

# %% [markdown]
# # Parsing sentences

# %% [markdown]
# For parsing I chose Stanford CoreNLP, because it's reliable and I've used it before.

# %%
from stanfordcorenlp import StanfordCoreNLP

# %% [markdown]
# Also, importing JSON to interpret the parsing result.

# %%
import json

# %% [markdown]
# Must load the parser first. I downloaded CoreNLP from URL. Unzipped it and using the location here for loading.

# %%
# location of the downloaded file after unzipping
coreNLP_location = 'C:\ds\phrasebase\stanford-corenlp-full-2018-02-27'

parser = StanfordCoreNLP(coreNLP_location, quiet=True)
props = {'annotators': 'parse', 'pipelineLanguage': 'en'}

# %% [markdown]
# Let's see how it works. Running this for the first time will load the pipeline, hence it could consume some time.

# %%
text = "Why did the chicken cross the road?"

result = json.loads(parser.annotate(text, properties=props))
parsed_tree_string = result['sentences'][0]['parse'];
print(parsed_tree_string)
# Out:
# (ROOT
#   (SBARQ
#     (WHADVP (WRB Why))
#     (SQ (VBD did)
#       (NP (DT the) (NN chicken))
#       (VP (VB cross)
#         (NP (DT the) (NN road))))
#     (. ?)))

# %% [markdown]
# There we have it, the parsed tree.

# %% [markdown]
# ### Extracting wh-phrases

# %% [markdown]
# Since we want to guess the expected entity type in answer for a given wh-question, we'll define a method to extract the wh-phrase from a query.
#
# Learning and testing will only happen for those rows that have a wh- question in query.

# %% [markdown]
# It is better to represent parsed tree into a proper tree instead of using a JSON string. That way we can chunk phrases using NLTK's tree library.

# %%
from nltk.tree import *

# %% [markdown]
# Now defining a method to chunk the parsed tree and extract wh-phrases (if any)
#
# - The method will accept a parsed tree (not parsed JSON string), along with a phrase as arguments.
# - The method will return those branches of the tree that contain given phrase as root.

# %%
def ExtractPhrases(myTree, phrase):
    myPhrases = []
    if (myTree.label() == phrase):
        myPhrases.append( myTree.copy(True) )
    for child in myTree:
        if (type(child) is Tree):
            list_of_phrases = ExtractPhrases(child, phrase)
            if (len(list_of_phrases) > 0):
                myPhrases.extend(list_of_phrases)
    return myPhrases

# %% [markdown]
# Testing the extraction method

# %%
# converting JSON to tree using NLTK's tree
parsed_tree = Tree.fromstring(parsed_tree_string)

ExtractPhrases(parsed_tree,"WHADVP")
# Out:
# [Tree('WHADVP', [Tree('WRB', ['Why'])])]

# %% [markdown]
# So it returned the wh-adverb from our query text. To see a list of all the constituent tags refer [Penn Treebank](http://www.surdeanu.info/mihai/teaching/ista555-fall13/readings/PennTreebankConstituents.html).

# %% [markdown]
# # Named Entity Recognition

# %% [markdown]
# While CoreNLP does recognise Named Entities, it's not accurate and offers fewer Named Entities compared to SpaCy.
#
# So let's try SpaCy.

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
ner = en_core_web_sm.load()

# %% [markdown]
# Let's see how it works

# %%
text = "Sachin Tendulkar is an Indian cricketer. He was born in Mumbai."
text_ner = ner(text)

# iterating over all entities and printing the entity with its ontology
for entity in text_ner.ents:
    print(entity,' - ',entity.label_)
# Out:
# Sachin Tendulkar  -  PERSON
# Indian  -  NORP
# Mumbai  -  GPE

# %% [markdown]
# Refer [SpaCy Entities](https://spacy.io/usage/linguistic-features#entity-types) to get a description of all entity types.

# %% [markdown]
# # Creating a dictionary

# %% [markdown]
# The aim is to record all the wh-phrases in a dictionary against all the named entities that occur in the answer passage for that wh-phrase.
#
# So let's define a dict for that

# %%
qa_dict = {}

# %% [markdown]
# Next, we need a method that would extract wh-phrases from query. The method should also populate our dict with that particular wh-phrase alongside an empty dictionary. This dictionary will maintain a score for all named entities expected in the answer passage for the query.

# %% [markdown]
# `CheckWh` method will take `query` string and `qa_dict` as arguments
# - This method returns 0 if no wh-phrase found in phrase
# - otherwise updates `qa_dict` with wh-phrase found and returns its value (answer named entities score)

# %%
def CheckWh(query, qa_dict):
    query = str(query)
    
    # removing all round parenthesis from the query, so that is doesn't trouble while parsing
    query = query.replace("("," ")
    query = query.replace(")"," ")
    
    # parsing the query
    r = json.loads(parser.annotate(query, properties=props))
    
    # we want to extract three types of wh-phrase
    # WHADVP, WHADJP, and WHNP
    
    # since it is a query, expecting only 1 sentence
    pADV = ExtractPhrases(Tree.fromstring(r["sentences"][0]['parse']),"WHADVP")
    # if found WHADVP, make it the wh-phrase
    p = pADV
    
    pADJ = ExtractPhrases(Tree.fromstring(r["sentences"][0]['parse']),"WHADJP")
    # if found WHADJP...
    if(len(pADJ) != 0):
        # ...and WHADVP was not found then make WHADJP the wh-phrase
        if(len(p) == 0):
            p = pADJ
        # else choose the one with fewer branch count
        elif(len(str(pADJ[0])) < len(str(p[0]))):
            p = pADJ
            
    pNP = ExtractPhrases(Tree.fromstring(r["sentences"][0]['parse']),"WHNP")
    # if found WHNP...
    if(len(pNP) != 0):
        # ...and WHADVP/WHADJ was not found then make WHNP the wh-phrase
        if(len(p) == 0):
            p = pNP
        # else choose the one with fewer branch count
        elif (len(str(pNP[0])) < len(str(p[0]))):
            p = pNP
            
    # update qa_dict if any wh-phrase found
    if(len(p) > 0):
        qphrase = ' '.join(word for word in p[0].leaves())
        if qphrase in qa_dict:
            # update existing entry
            qa_dict[qphrase]['size'] += 1 
        else:
            # new entry
            qa_dict[qphrase] = {}
            qa_dict[qphrase]['size'] = 1 
            qa_dict[qphrase]['answer_ner'] = {} # create empty value
        return qa_dict[qphrase]
    else:
        return 0

# %% [markdown]
# Testing the method

# %%
CheckWh("what is cricket", qa_dict)
qa_dict
# Out:
# {'what': {'size': 1, 'answer_ner': {}}}

# %% [markdown]
# # Training

# %% [markdown]
# The dataset has 5+ million rows, which is just...

# %% [markdown]
# <img src="https://media1.tenor.com/images/4d88ca458dd87a78979baff245791a8e/tenor.gif?itemid=7357158" alt="Trump Yuge" align="left"></img>

# %% [markdown]
# It would be heartbreaking to learn that the algorithm is not learning well after building the feature for 5 million rows.
# So it's best we first build out dictionary on a smaller subset, say 1 million rows. It's still big, but remember not all queries in search engines have a wh-phrase so the actual count of queries to learn from, will be far less.

# %%
subset = dataset[0:1000000]

# %% [markdown]
# Now a method `TrainFeature` to accept a dataframe as argument.
# - This method checks for wh-phrase in the query using `CheckWh`
#     - if found, then for the 10 rows(passages), all the named entities found in answer passages are rewarded with good score and those from incorrect passages are punished.
#         - We'll reward the named entities with +1
#         - and punish with -(1/9). This is to equalize the score to 0 if the named entity is present in all the incorrect passages and in the correct passage. That would indicate the entity is pretty useless and nothing to learn from it.
#     - also, in the `qa_dict` we'll save/update this wh-phrase with the named entity scores
# - If query doesn't have a wh-phrase then skip next 10 rows
# - Also record the no. of wh-phrases in `wh_query_count`

# %%
# this is the dictionary we are going to populate
qa_dict = {}

def TrainFeature(t):
    
    # to save the no. of wh-phrase in subset
    #wh_query_count = 0
    
    # NOTE: It is not the most elegant solution to just iterate over the dataframe in Pandas.
    # I know I'm committing a sacrilege but desperate times call for desperate measures. 
    # If you could suggest a more efficient and beautiful way of building this feature without looping then feel free to help.

    # iterator
    i=0

    # let's loop over each row of the dataframe (sorry!)
    while i < t.id.size:
        trow = t.iloc[i]
        # Query of 1 in every 10 rows will be considered for checking wh-phrase
        if(i%10 == 0):
            # check for wh-phrase in query, and populate if it has any...
            qdict_entry = CheckWh(trow['query'],qa_dict)
            
            # in case no wh-phrase was found...
            if qdict_entry == 0:
                # ...skip the 10 rows (passages)
                i += 10
                continue
            #else:
             #   wh_query_count += 1

        # wh-phrase was found, so time to assign scores to the named entities
        
        # if the passage is correct answer...
        if trow['label'] == 1:
            # get its named entities...
            passage_ner = ner(str(trow['passage']))
            # ...iterate over each entity
            for X in passage_ner.ents:
                # either update the wh-phrase dictionary...
                if X.label_ in qdict_entry['answer_ner']:
                    # reward the named entity
                    qdict_entry['answer_ner'][X.label_] += 1
                # ...or create a new entry for the wh-phrase
                else:    
                    qdict_entry['answer_ner'][X.label_] = {}
                    # and then reward the named entity
                    qdict_entry['answer_ner'][X.label_] = 1
            #print("query in qdict: ",qdict_entry)
        
        # ...otherwise passage is incorrect for the query
        else:
            # still... get named entities for the passage
            passage_ner = ner(str(trow['passage']))
            # iterate over all entities
            for X in passage_ner.ents:
                # either update the wh-phrase dictionary...
                if X.label_ in qdict_entry['answer_ner']:
                    # punish the named entity by decreasing the score
                    qdict_entry['answer_ner'][X.label_] -= (1/9)
                # ...or create a new entry for the wh-phrase
                else:    
                    qdict_entry['answer_ner'][X.label_] = {}
                    # and then punish the named entity
                    qdict_entry['answer_ner'][X.label_] = (1/9)
        
        # increment row
        i+=1
    #return wh_query_count    
print(qa_dict)
# Out:
# {}

# %% [markdown]
# Let's test the  `TrainFeature` method on 10 queries

# %%
# this is the dictionary we are going to populate
qa_dict = {}

# to save the no. of wh-phrase in subset
#wh_query_count = 0

#wh_query_count = 
TrainFeature(subset[0:200])

# %% [markdown]
# Number of wh-phrases in ten queries

# %%
#wh_query_count
# Out:
# 3

# %% [markdown]
# Our dictionary has recorded three wh-phrases from the ten queries.
# `size` attribute indicates the no. of times that particular wh-phrase was found
# All the negative scores simply mean that named entity is not to be trusted for the wh-phrase
# Checking out all the scores of named entities reveals the scales are messed up.

# %%
qa_dict
# Out:
# {'what': {'size': 1,
#   'answer_ner': {'DATE': 0.1111111111111111,
#    'CARDINAL': -1.2222222222222225,
#    'ORG': 1.0,
#    'PERSON': 0.0,
#    'PERCENT': 0.1111111111111111,
#    'NORP': 0.1111111111111111}},
#  'how often': {'size': 1,
#   'answer_ner': {'CARDINAL': 2.5555555555555554,
#    'ORG': 0.7777777777777778,
#    'DATE': -0.555555555555556,
#    'GPE': -0.1111111111111111,
#    'PERSON': 0.0,
#    'TIME': -0.5555555555555556,
#    'QUANTITY': 0.0,
#    'LAW': 0.1111111111111111}},
#  'how many': {'size': 3,
#   'answer_ner': {'DATE': 0.6666666666666643,
#    'TIME': -0.5555555555555556,
#    'GPE': -2.111111111111112,
#    'CARDINAL': -1.4444444444444455,
#    'ORG': -0.5555555555555562,
#    'PERSON': -0.8888888888888902,
#    'NORP': 0.4444444444444445,
#    'PERCENT': 0.1111111111111111,
#    'QUANTITY': 0.1111111111111111,
#    'LOC': 0.1111111111111111,
#    'WORK_OF_ART': 0.1111111111111111,
#    'PRODUCT': 0.1111111111111111}},
#  'how much': {'size': 1,
#   'answer_ner': {'PERSON': 0.1111111111111111,
#    'MONEY': 2.6666666666666656,
#    'ORG': -1.4444444444444449,
#    'DATE': 1.4444444444444442,
#    'ORDINAL': 2.333333333333333,
#    'GPE': -0.5555555555555556,
#    'CARDINAL': 0.8888888888888888}},
#  'how far': {'size': 1,
#   'answer_ner': {'GPE': -1.6666666666666672,
#    'PERSON': 1.1111111111111103,
#    'ORG': 1.3333333333333333,
#    'LOC': -0.5555555555555556,
#    'QUANTITY': 3.8888888888888915,
#    'CARDINAL': 1.7777777777777772,
#    'TIME': 0.33333333333333315,
#    'DATE': 0.44444444444444425,
#    'MONEY': 1,
#    'ORDINAL': 0.0,
#    'NORP': 0.1111111111111111}}}

# %% [markdown]
# We need to normalize the scores. And even remove negative ones since they don't come from correct passages.

# %%
def NormalizeScore(qa_dict):
    qdict_norm = {}
    for k1, v1 in qa_dict.items():
        d = {}
        for k2,v2 in v1['answer_ner'].items():
            if v2 > 0.1:
                d[k2] = v2
        l = [v for k,v in d.items()]

        if len(l) > 0:
            max_ = max(l)
            for k,v in d.items():
                d[k] = v/max_
            if k1 in qdict_norm:
                qdict_norm[k1]['norm_ner'] = d
            else:
                qdict_norm[k1] = {}
                qdict_norm[k1]['norm_ner'] = d
    return qdict_norm
            
qdict_norm = NormalizeScore(qa_dict)

for k,v in qdict_norm.items():
    print("wh-phrase: ",k)
    for k1,v1 in v['norm_ner'].items():
        print(k1," ",v1)
    print("\n")
# Out:
# wh-phrase:  what
# DATE   0.1111111111111111
# ORG   1.0
# PERCENT   0.1111111111111111
# NORP   0.1111111111111111
#
#
# wh-phrase:  how often
# CARDINAL   1.0
# ORG   0.30434782608695654
# LAW   0.043478260869565216
#
#
# wh-phrase:  how many
# DATE   1.0
# TIME   0.08333333333333337
# NORP   0.33333333333333354
# PERCENT   0.08333333333333337
# QUANTITY   0.08333333333333337
# LOC   0.08333333333333337
# WORK_OF_ART   0.08333333333333337

# %% [markdown]
# The results are not that bad.
# - 'what' is answered highly using an ORG entity
# - 'how often' is answered highly using a CARDINAL entity
# - 'how many' is answered highly using a DATE, not quite correct... but ok.

# %% [markdown]
# Time to train it over 100,000 queries i.e. 1 million rows

# %%
# this is the dictionary we are going to populate
qa_dict = {}

# to save the no. of wh-phrase in subset
#wh_query_count = 0

#wh_query_count = 
TrainFeature(subset)
#qa_dict_norm = NormalizeScore(qa_dict)

# %% [markdown]
# Let's check how many from the 100,000 queries contained a wh-phrase

# %%
#wh_query_count

# %% [markdown]
# Running this took a lot of time, so to be safe I'll use pickle to dump this dictionary.

# %%
import pickle

# %% [markdown]
# Saving as a pickle

# %%
output = open('qa_dict_1mil_queries_norm.pkl', 'wb')
pickle.dump(qa_dict_norm, output)
output.close()

# %% [markdown]
# <img src="https://media1.tenor.com/images/1756eb5631ade0eb64d57d256a5847f2/tenor.gif?itemid=9423244" align="left">

# %% [markdown]
# Read that pickle again... we'll use this to build a feature for training samples.

# %%
#pkl_file = open('wh_q_ans_dict_1mil_norm.pkl', 'rb')
pkl_file = open('qa_dict_10k_queries_norm.pkl', 'rb')
qa_ner_dict = pickle.load(pkl_file)
pkl_file.close()

# %% [markdown]
# Number of unique wh-phrase is...

# %%
len(qa_ner_dict)
# Out:
# 6249

# %% [markdown]
# So of all the 100,000 queries we parsed, we found 6249 unique wh-phrase. Shoot! I forgot to save the actual no. of queries that had a wh-phrase. Nevermind,

# %%
qa_ner_dict
# Out:
# {'what': {'norm_ner': {'DATE': 0.2418223643619053,
#    'ORG': 0.27209224036509844,
#    'PERSON': 0.2820793356910595,
#    'NORP': 0.24185041800009802,
#    'GPE': 1.0,
#    'QUANTITY': 0.20821410537015195,
#    'LOC': 0.14618751052058074,
#    'MONEY': 0.16905122594456373,
#    'FAC': 0.023256466363745502,
#    'ORDINAL': 0.01660775402573,
#    'EVENT': 0.013521853784470026,
#    'LANGUAGE': 0.007041463277805692}},
#  'how often': {'norm_ner': {'CARDINAL': 0.37242798353911627,
#    'ORG': 0.38271604938273435,
#    'DATE': 1.0,
#    'GPE': 0.13374485596708402,
#    'PERSON': 0.034979423868313805,
#    'LAW': 0.026748971193416664,
#    'ORDINAL': 0.03703703703703852,
#    'PRODUCT': 0.026748971193416633,
#    'LOC': 0.010288065843622051,
#    'FAC': 0.022633744855967947,
#    'NORP': 0.2222222222222315,
#    'WORK_OF_ART': 0.010288065843621796,
#    'LANGUAGE': 0.01440329218107052}},
#  'how many': {'norm_ner': {'DATE': 0.35156555772983117,
#    'TIME': 0.00900195694715671,
#    'GPE': 0.3557729941289829,
#    'CARDINAL': 1.0,
#    'PERSON': 0.09119373776900025,
#    'NORP': 0.08767123287663926,
#    'PERCENT': 0.12504892367896323,
#    'QUANTITY': 0.3834637964773024,
#    'LOC': 0.040215264187831785,
#    'WORK_OF_ART': 0.010176125244611077,
#    'ORDINAL': 0.0014677103718192261,
#    'MONEY': 0.02935420743637747,
#    'EVENT': 0.008121330724064737,
#    'LANGUAGE': 0.01722113502934157}},
#  'how much': {'norm_ner': {'PERSON': 0.08431109621182557,
#    'MONEY': 1.0,
#    'ORG': 0.010811263828347894,
#    'DATE': 0.1334227287964546,
#    'GPE': 0.21689574254102623,
#    'PERCENT': 0.04316124706669502,
#    'TIME': 0.004609453570230795,
#    'QUANTITY': 0.22100234663087243,
#    'FAC': 0.004944686557156273,
#    'LOC': 0.02958431109620483,
#    'NORP': 0.02413677505866078}},
#  'how far': {'norm_ner': {'GPE': 1.0,
#    'ORG': 0.17543859649121973,
#    'LOC': 0.030019493177388567,
#    'QUANTITY': 0.8097465886939575,
#    'CARDINAL': 0.027290448343082266,
#    'TIME': 0.06237816764132711,
#    'DATE': 0.02923976608187303,
#    'WORK_OF_ART': 0.026510721247563842,
#    'LANGUAGE': 0.004678362573099485}},
#  'how long': {'norm_ner': {'DATE': 1.0,
#    'PERSON': 0.06106460613860773,
#    'GPE': 0.23878514702713594,
#    'TIME': 0.5609572869712964,
#    'ORG': 0.06117192530577191,
#    'FAC': 0.007512341704225058,
#    'MONEY': 0.05408886027041709,
#    'EVENT': 0.0124490233955726,
#    'NORP': 0.023502897617503977,
#    'QUANTITY': 0.14305644988186908,
#    'LOC': 0.016205194247683623,
#    'LAW': 0.0026829791800803376,
#    'LANGUAGE': 0.004722043356941287}},
#  'how': {'norm_ner': {'GPE': 1.0,
#    'CARDINAL': 0.6261562998401959,
#    'FAC': 0.010526315789472874,
#    'PRODUCT': 0.07304625199361174,
#    'PERSON': 0.09059011164273198,
#    'ORG': 0.3272727272725225,
#    'LOC': 0.0915470494417725,
#    'DATE': 0.7964912280700664,
#    'EVENT': 0.015311004784687065,
#    'QUANTITY': 0.1881977671451059,
#    'ORDINAL': 0.007655502392346496,
#    'NORP': 0.1620414673045933,
#    'WORK_OF_ART': 0.0666666666666579,
#    'MONEY': 0.15725677830938178,
#    'TIME': 0.3189792663476195,
#    'LANGUAGE': 0.005422647527910247,
#    'LAW': 0.008612440191386343}},
#  'that': {'norm_ner': {'CARDINAL': 0.6710182767624792,
#    'PERSON': 0.5300261096606339,
#    'ORG': 1.0,
#    'GPE': 0.8798955613577772,
#    'DATE': 0.42297650130553427,
#    'LOC': 0.020887728459532354,
#    'PERCENT': 0.03133159268929796,
#    'TIME': 0.19321148825067153,
#    'EVENT': 0.08616187989556943,
#    'LAW': 0.16449086161881482,
#    'PRODUCT': 0.03133159268929809,
#    'QUANTITY': 0.30809399477809873,
#    'MONEY': 0.6214099216710786,
#    'WORK_OF_ART': 0.03133159268929794}},
#  'which organisms': {'norm_ner': {'ORG': 1.0,
#    'LAW': 0.07142857142857142,
#    'NORP': 0.4285714285714285,
#    'ORDINAL': 0.07142857142857142,
#    'DATE': 0.14285714285714274,
#    'FAC': 0.5714285714285714,
#    'PRODUCT': 0.07142857142857142}},
#  'how big': {'norm_ner': {'CARDINAL': 0.19023904382469228,
#    'ORG': 0.021912350597611922,
#    'PERSON': 0.13745019920319065,
#    'LOC': 0.044820717131474785,
#    'QUANTITY': 1.0,
#    'WORK_OF_ART': 0.03087649402390477,
#    'LAW': 0.0019920318725099866,
#    'GPE': 0.27788844621514464,
#    'PRODUCT': 0.007968127490039932,
#    'LANGUAGE': 0.003984063745019968,
#    'ORDINAL': 0.028884462151394768}},
#  'when': {'norm_ner': {'DATE': 1.0,
#    'FAC': 0.020751074844267303,
#    'GPE': 0.44937264192377757,
#    'QUANTITY': 0.061814512591061486,
#    'ORG': 0.14350267614298573,
#    'PERSON': 0.16140212336592777,
#    'NORP': 0.06743002544531815,
#    'ORDINAL': 0.07861717995966935,
#    'LOC': 0.03632534877600709,
#    'EVENT': 0.03325436518383594,
#    'MONEY': 0.07453715890149747,
#    'LAW': 0.00710713345617652,
#    'TIME': 0.013600070193915594,
#    'PRODUCT': 0.00048258313591352964,
#    'WORK_OF_ART': 0.018952355883134958,
#    'LANGUAGE': 0.007370360621219982}},
#  'how many brothers': {'norm_ner': {'CARDINAL': 1.0,
#    'WORK_OF_ART': 0.07142857142857144,
#    'NORP': 0.07142857142857144}},
#  'how heavy': {'norm_ner': {'QUANTITY': 1.0,
#    'ORDINAL': 0.10389610389610364,
#    'PERCENT': 0.012987012987012965,
#    'NORP': 0.37662337662337597,
#    'PRODUCT': 0.012987012987012965,
#    'FAC': 0.10389610389610372,
#    'EVENT': 0.09090909090909075}},
#  'how titanic': {'norm_ner': {'CARDINAL': 0.24137931034482743,
#    'ORDINAL': 0.27586206896551724,
#    'TIME': 1.0,
#    'EVENT': 0.034482758620689655,
#    'FAC': 0.034482758620689655}},
#  'how soon': {'norm_ner': {'DATE': 1.0,
#    'ORDINAL': 0.08048780487804875,
#    'GPE': 0.19512195121951345,
#    'MONEY': 0.026829268292682854,
#    'NORP': 0.17804878048780498,
#    'TIME': 0.043902439024390685,
#    'QUANTITY': 0.11219512195121953,
#    'LANGUAGE': 0.05121951219512191}},
#  'how thick os earth crust': {'norm_ner': {'ORG': 0.3333333333333333,
#    'CARDINAL': 1.0,
#    'QUANTITY': 0.4761904761904788}},
#  'how fast': {'norm_ner': {'CARDINAL': 0.11832061068702919,
#    'PERSON': 0.035623409669211736,
#    'ORG': 0.21501272264631624,
#    'GPE': 0.13867684478371795,
#    'ORDINAL': 0.011450381679389405,
#    'DATE': 0.03435114503816876,
#    'QUANTITY': 1.0,
#    'PRODUCT': 0.04961832061068766,
#    'LOC': 0.0038167938931297414,
#    'WORK_OF_ART': 0.024173027989822172,
#    'TIME': 0.22519083969466003,
#    'LAW': 0.04071246819338474}},
#  'how old': {'norm_ner': {'GPE': 0.251608291636851,
#    'DATE': 1.0,
#    'PERSON': 0.14331665475335986,
#    'TIME': 0.07862759113652076,
#    'QUANTITY': 0.02859185132237112,
#    'FAC': 0.013938527519655911,
#    'NORP': 0.008934953538241638,
#    'PRODUCT': 0.03967119370979001,
#    'LAW': 0.010364546104359506}},
#  'approximately what': {'norm_ner': {'QUANTITY': 0.12499999999999985,
#    'CARDINAL': 1.0,
#    'NORP': 0.2249999999999998,
#    'ORDINAL': 0.024999999999999977,
#    'MONEY': 0.024999999999999977}},
#  'how common': {'norm_ner': {'PERSON': 0.45833333333333326,
#    'QUANTITY': 0.35416666666666663,
#    'CARDINAL': 1.0,
#    'GPE': 0.5625000000000002,
#    'PRODUCT': 0.2916666666666666,
#    'LOC': 0.3958333333333333,
#    'ORDINAL': 0.125}},
#  'How much': {'norm_ner': {'ORG': 0.5365853658536572,
#    'DATE': 0.39024390243902307,
#    'GPE': 0.24390243902438968,
#    'CARDINAL': 1.0,
#    'MONEY': 0.24390243902439018,
#    'ORDINAL': 0.17073170731707268,
#    'NORP': 0.3902439024390237,
#    'LOC': 0.09756097560975587,
#    'EVENT': 0.024390243902438987,
#    'QUANTITY': 0.17073170731707288}},
#  'How long': {'norm_ner': {'LAW': 0.1111111111111111, 'LOC': 1.0}},
#  'what sex': {'norm_ner': {'DATE': 0.9999999999999944,
#    'PERCENT': 1.0,
#    'TIME': 1.0}},
#  'how cold': {'norm_ner': {'ORG': 0.4666666666666651,
#    'TIME': 0.7333333333333316,
#    'GPE': 0.33333333333333215,
#    'LANGUAGE': 0.5999999999999988,
#    'FAC': 0.7333333333333317,
#    'PRODUCT': 0.4666666666666657,
#    'MONEY': 1.0,
#    'NORP': 0.133333333333333,
#    'ORDINAL': 0.19999999999999948}},
#  'how early': {'norm_ner': {'DATE': 1.0,
#    'NORP': 0.05472636815920379,
#    'TIME': 0.10447761194029818,
#    'GPE': 0.41791044776119296,
#    'CARDINAL': 0.3432835820895522,
#    'ORG': 0.06467661691542285,
#    'QUANTITY': 0.08955223880596985,
#    'MONEY': 0.034825870646766025,
#    'PERCENT': 0.16915422885572207,
#    'WORK_OF_ART': 0.04975124378109436,
#    'LAW': 0.004975124378109437}},
#  'how many ways': {'norm_ner': {'DATE': 1.0}},
#  'how tall': {'norm_ner': {'PERSON': 0.09969788519637843,
#    'QUANTITY': 1.0,
#    'LOC': 0.04431017119838922,
#    'GPE': 0.048338368580062484,
#    'CARDINAL': 0.25931520644510414,
#    'FAC': 0.001510574018126888,
#    'TIME': 0.0025176233635448393,
#    'PERCENT': 0.03272910372608299}},
#  'why': {'norm_ner': {'PERSON': 0.5181762168821835,
#    'DATE': 0.24984596426366049,
#    'ORG': 0.3786198398026686,
#    'LOC': 0.26278496611210245,
#    'TIME': 0.07732593961798424,
#    'NORP': 0.35613062230431397,
#    'GPE': 1.0,
#    'QUANTITY': 0.18792359827477,
#    'MONEY': 0.044054220579171494,
#    'ORDINAL': 0.025569932224274807,
#    'EVENT': 0.05329636475661856,
#    'LANGUAGE': 0.018484288354896627}},
#  'baked serloin steak how long': {'norm_ner': {'QUANTITY': 0.2272727272727273,
#    'PERSON': 1.0}},
#  'what day': {'norm_ner': {'DATE': 0.6037151702786465,
#    'GPE': 1.0,
#    'PERSON': 0.015479876160990726,
#    'NORP': 0.23529411764706026,
#    'LOC': 0.08359133126935003,
#    'ORG': 0.4674922600619246,
#    'ORDINAL': 0.027863777089783326,
#    'TIME': 0.4148606811145527,
#    'EVENT': 0.05882352941176483,
#    'LAW': 0.01547987616099075,
#    'WORK_OF_ART': 0.0030959752321981543,
#    'QUANTITY': 0.012383900928792596}},
#  'who': {'norm_ner': {'PERSON': 1.0,
#    'DATE': 0.4338667389939837,
#    'ORG': 0.30774794322504284,
#    'GPE': 0.6042401229558702,
#    'WORK_OF_ART': 0.001084892866831758,
#    'LOC': 0.07146731760249125,
#    'PRODUCT': 0.00542446433415598,
#    'ORDINAL': 0.11391375101726131,
#    'NORP': 0.296853810686782,
#    'FAC': 0.011662598318434587,
#    'MONEY': 0.011074948015565727,
#    'EVENT': 0.022104692161683172,
#    'LANGUAGE': 0.01649941234972263,
#    'QUANTITY': 0.08118614953452237}},
#  'what county': {'norm_ner': {'PERSON': 0.030633818009235567,
#    'GPE': 1.0,
#    'DATE': 0.06847305518402484,
#    'CARDINAL': 0.08836346377875408,
#    'LOC': 0.022522328170171545,
#    'QUANTITY': 0.04651162790698346,
#    'ORDINAL': 0.016050394787939026,
#    'EVENT': 0.00021573111274112463}},
#  'where': {'norm_ner': {'ORG': 0.06809110991501112,
#    'PERSON': 0.11208672891679324,
#    'PRODUCT': 0.0010766860346416867,
#    'LOC': 0.13408453841755652,
#    'QUANTITY': 0.09196383820026967,
#    'DATE': 0.12283502571085532,
#    'GPE': 1.0,
#    'EVENT': 0.0029330412667820595,
#    'NORP': 0.051959382947629994,
#    'MONEY': 0.0238541647330028,
#    'ORDINAL': 0.02201637305318248,
#    'FAC': 0.026545879819606252,
#    'WORK_OF_ART': 0.0007239785405348869,
#    'LAW': 0.0010581224823201071}},
#  'which': {'norm_ner': {'ORG': 0.0966638152267017,
#    'GPE': 1.0,
#    'LOC': 0.08041060735671945,
#    'PERSON': 0.10778443113773342,
#    'DATE': 0.18562874251498346,
#    'PRODUCT': 0.029940119760480388,
#    'QUANTITY': 0.1411462788708362,
#    'TIME': 0.04790419161676877,
#    'NORP': 0.2771599657827321,
#    'ORDINAL': 0.06672369546621448,
#    'EVENT': 0.03849443969204609,
#    'LANGUAGE': 0.01539777587681841}},
#  'what two layers of meninges': {'norm_ner': {'CARDINAL': 1.0,
#    'PERSON': 0.36363636363636365,
#    'ORG': 0.045454545454545456,
#    'GPE': 0.045454545454545456}},
#  'what year': {'norm_ner': {'DATE': 1.0,
#    'QUANTITY': 0.06998521439133192,
#    'GPE': 0.7318876293740875,
#    'ORG': 0.4445539674716598,
#    'NORP': 0.12715623459833683,
#    'MONEY': 0.08230655495318624,
#    'PERSON': 0.7511089206505572,
#    'PERCENT': 0.05273533760473617,
#    'ORDINAL': 0.18974864465254843,
#    'LAW': 0.037456875308036576,
#    'LOC': 0.1103992114342139,
#    'EVENT': 0.020699852143915298,
#    'FAC': 0.004435682602267644,
#    'WORK_OF_ART': 0.07442089699359966}},
#  'what extent': {'norm_ner': {'EVENT': 0.09999999999999999,
#    'LAW': 1.0,
#    'WORK_OF_ART': 0.09999999999999999}},
#  'what reaction': {'norm_ner': {'MONEY': 0.6249999999999999,
#    'DATE': 0.18749999999999978,
#    'QUANTITY': 1.0,
#    'LOC': 0.0625}},
#  'which supergroup': {'norm_ner': {'CARDINAL': 0.22222222222222215,
#    'PERSON': 0.33333333333333337,
#    'ORDINAL': 0.1111111111111111,
#    'LANGUAGE': 1.0}},
#  'what company': {'norm_ner': {'ORG': 1.0,
#    'DATE': 0.8453608247422607,
#    'GPE': 0.814432989690711,
#    'PERSON': 0.42268041237112886,
#    'NORP': 0.5773195876288585,
#    'ORDINAL': 0.3505154639175212,
#    'LAW': 0.05154639175257664,
#    'EVENT': 0.34020618556700605,
#    'FAC': 0.06185567010309197}},
#  'what language': {'norm_ner': {'CARDINAL': 0.18930041152264113,
#    'NORP': 0.7489711934156441,
#    'GPE': 1.0,
#    'PERSON': 0.48559670781894354,
#    'LOC': 0.2510288065843676,
#    'ORG': 0.5020576131687389,
#    'ORDINAL': 0.08230452674897275,
#    'PERCENT': 0.15226337448559984,
#    'PRODUCT': 0.07613168724279985,
#    'LANGUAGE': 0.13786008230453117,
#    'DATE': 0.23045267489712598,
#    'WORK_OF_ART': 0.02057613168724317,
#    'EVENT': 0.024691358024691815,
#    'QUANTITY': 0.12139917695473529,
#    'MONEY': 0.2777777777777836,
#    'TIME': 0.04732510288065926,
#    'LAW': 0.04938271604938364}},
#  'what month': {'norm_ner': {'PERSON': 0.026666666666667515,
#    'DATE': 1.0,
#    'GPE': 0.05666666666666885,
#    'ORG': 0.49666666666668874,
#    'ORDINAL': 0.09666666666667043,
#    'LOC': 0.10666666666667096,
#    'QUANTITY': 0.11000000000000412,
#    'MONEY': 0.036666666666668055,
#    'EVENT': 0.026666666666667647,
#    'WORK_OF_ART': 0.04000000000000151,
#    'LAW': 0.01666666666666729}},
#  'what form at room temperature': {'norm_ner': {'PERSON': 1.0,
#    'ORG': 0.1111111111111111}},
#  'how long for results': {'norm_ner': {'NORP': 0.05555555555555555,
#    'TIME': 1.0}},
#  'forest service what agency': {'norm_ner': {'CARDINAL': 0.11764705882352904,
#    'GPE': 0.41176470588235176,
#    'ORG': 1.0,
#    'NORP': 0.17647058823529357,
#    'QUANTITY': 0.11764705882352904,
#    'MONEY': 0.23529411764705815,
#    'ORDINAL': 0.20588235294117588,
#    'PERSON': 0.02941176470588227}},
#  'what county in ca': {'norm_ner': {'PERSON': 0.48214285714285715,
#    'CARDINAL': 0.03571428571428569,
#    'GPE': 1.0,
#    'DATE': 0.1607142857142857,
#    'LOC': 0.17857142857142858,
#    'EVENT': 0.017857142857142856,
#    'FAC': 0.1607142857142857}},
#  'valley state bank belle plaine': {'norm_ner': {'PERSON': 1.0}},
#  'walnutport pa what county': {'norm_ner': {'GPE': 1.0,
#    'TIME': 0.07692307692307684,
#    'QUANTITY': 0.07692307692307684}},
#  'what temperature in kelvin': {'norm_ner': {'ORG': 0.13043478260869557,
#    'PERSON': 1.0,
#    'GPE': 0.23188405797101433,
#    'LOC': 0.014492753623188396,
#    'QUANTITY': 0.1304347826086955,
#    'MONEY': 0.11594202898550716,
#    'NORP': 0.014492753623188396,
#    'FAC': 0.014492753623188396,
#    'PERCENT': 0.014492753623188396}},
#  'what .': {'norm_ner': {'GPE': 1.0,
#    'FAC': 0.10810810810810773,
#    'WORK_OF_ART': 0.027027027027026942,
#    'NORP': 0.16216216216216162}},
#  'what a wonderful world meaning': {'norm_ner': {'PERSON': 1.0,
#    'DATE': 0.16000000000000003,
#    'FAC': 0.04000000000000001,
#    'WORK_OF_ART': 0.3600000000000001}},
#  'what about flexible response': {'norm_ner': {'PERSON': 1.0,
#    'DATE': 0.2941176470588235,
#    'GPE': 0.2941176470588235,
#    'EVENT': 0.05882352941176472,
#    'ORG': 0.05882352941176472,
#    'CARDINAL': 0.05882352941176472,
#    'WORK_OF_ART': 0.05882352941176472}},
#  'what about reapportionment': {'norm_ner': {'ORG': 1.0,
#    'NORP': 0.08333333333333334,
#    'ORDINAL': 0.08333333333333334}},
#  'what about the study of the humanities as the study of what it means to be human': {'norm_ner': {'DATE': 1.0,
#    'WORK_OF_ART': 1.0,
#    'PERCENT': 1.0,
#    'CARDINAL': 1.0,
#    'NORP': 1.0,
#    'GPE': 1.0,
#    'PERSON': 1.0}},
#  'what act': {'norm_ner': {'DATE': 1.0, 'CARDINAL': 0.08333333333333333}},
#  'what action': {'norm_ner': {'ORG': 1.0, 'GPE': 0.20000000000000007}},
#  'what actor': {'norm_ner': {'ORG': 0.24999999999999872,
#    'PERSON': 1.0,
#    'DATE': 0.2833333333333321,
#    'NORP': 0.0666666666666664,
#    'ORDINAL': 0.13333333333333283,
#    'LOC': 0.016666666666666604,
#    'EVENT': 0.016666666666666604,
#    'LANGUAGE': 0.016666666666666604}},
#  'what actress': {'norm_ner': {'GPE': 0.7058823529411763,
#    'ORDINAL': 0.029411764705882356,
#    'CARDINAL': 1.0,
#    'EVENT': 0.26470588235294124,
#    'NORP': 0.7941176470588236,
#    'PRODUCT': 0.23529411764705885,
#    'LOC': 0.029411764705882356,
#    'LAW': 0.029411764705882356,
#    'TIME': 0.08823529411764708,
#    'FAC': 0.029411764705882356,
#    'PERCENT': 0.26470588235294124}},
#  'what acts': {'norm_ner': {'ORG': 0.3333333333333326,
#    'DATE': 1.0,
#    'GPE': 0.49999999999999967,
#    'NORP': 0.41666666666666663,
#    'LOC': 0.6666666666666667,
#    'CARDINAL': 0.6666666666666667,
#    'FAC': 0.08333333333333334}},
#  'what adobe suite': {'norm_ner': {'ORG': 1.0,
#    'GPE': 0.45454545454545375,
#    'PRODUCT': 0.5909090909090899,
#    'PERCENT': 0.02272727272727269,
#    'FAC': 0.02272727272727269,
#    'TIME': 0.02272727272727269}},
#  'what affect': {'norm_ner': {'LOC': 1.0, 'GPE': 1.0, 'EVENT': 1.0}},
#  'what african american physician': {'norm_ner': {'PERSON': 0.5882352941176466,
#    'ORDINAL': 0.6470588235294116,
#    'NORP': 0.17647058823529402,
#    'GPE': 0.764705882352941,
#    'CARDINAL': 1.0}},
#  'what age': {'norm_ner': {'GPE': 0.19701492537314932,
#    'DATE': 1.0,
#    'ORDINAL': 0.1432835820895624,
#    'TIME': 0.08805970149254325,
#    'PERCENT': 0.022388059701493983,
#    'MONEY': 0.06567164179104928,
#    'LANGUAGE': 0.008955223880597591,
#    'EVENT': 0.03432835820895744}},
#  'what age start': {'norm_ner': {'PERCENT': 1.0,
#    'PERSON': 0.7999999999999999,
#    'DATE': 1.0}},
#  'what age to babies': {'norm_ner': {'DATE': 1.0,
#    'ORDINAL': 0.12499999999999997,
#    'PERCENT': 0.06250000000000003}},
#  'what age to dogwoods': {'norm_ner': {'PRODUCT': 1.0,
#    'LOC': 1.0,
#    'TIME': 1.0,
#    'EVENT': 1.0}},
#  'what agency': {'norm_ner': {'ORG': 1.0,
#    'PERSON': 0.19512195121951192,
#    'LAW': 0.19512195121951192,
#    'DATE': 0.4634146341463409,
#    'TIME': 0.02439024390243899,
#    'FAC': 0.02439024390243899,
#    'PRODUCT': 0.02439024390243899,
#    'MONEY': 0.21951219512195094}},
#  'what ages': {'norm_ner': {'CARDINAL': 1.0,
#    'DATE': 0.8795180722891569,
#    'GPE': 0.08433734939759033,
#    'NORP': 0.04819277108433735,
#    'MONEY': 0.012048192771084338,
#    'ORDINAL': 0.7349397590361446,
#    'FAC': 0.012048192771084338,
#    'TIME': 0.0963855421686747}},
#  'what air force base': {'norm_ner': {'ORG': 0.11111111111111077,
#    'PERSON': 0.29629629629629634,
#    'GPE': 1.0,
#    'QUANTITY': 0.6296296296296298,
#    'LOC': 0.6296296296296298,
#    'DATE': 0.03703703703703704,
#    'FAC': 0.03703703703703704,
#    'LAW': 0.03703703703703704}},
#  'what airport': {'norm_ner': {'ORG': 0.981220657276996,
#    'GPE': 1.0,
#    'MONEY': 0.028169014084506963,
#    'FAC': 0.4084507042253524,
#    'PERSON': 0.04225352112676027,
#    'QUANTITY': 0.4507042253521119,
#    'NORP': 0.0751173708920186,
#    'WORK_OF_ART': 0.0046948356807511625}},
#  'what alabama county': {'norm_ner': {'CARDINAL': 0.1578947368421052,
#    'GPE': 1.0,
#    'DATE': 0.10526315789473686,
#    'PRODUCT': 0.05263157894736846,
#    'ORDINAL': 0.05263157894736846,
#    'LOC': 0.05263157894736846,
#    'QUANTITY': 0.05263157894736846}},
#  'what album': {'norm_ner': {'CARDINAL': 0.06666666666666674,
#    'PERSON': 0.028571428571428165,
#    'ORG': 1.0,
#    'DATE': 0.6571428571428573,
#    'ORDINAL': 0.37142857142857066,
#    'PRODUCT': 0.28571428571428487,
#    'NORP': 0.3809523809523799,
#    'EVENT': 0.16190476190476144,
#    'LOC': 0.009523809523809497}},
#  'what alias mean': {'norm_ner': {'ORDINAL': 1.0,
#    'DATE': 0.05555555555555555}},
#  'what amazed pilot': {'norm_ner': {'DATE': 0.5555555555555554,
#    'ORDINAL': 0.1111111111111111,
#    'FAC': 0.1111111111111111,
#    'LOC': 1.0,
#    'WORK_OF_ART': 0.1111111111111111}},
#  'what amendment': {'norm_ner': {'DATE': 0.44615384615384535,
#    'LAW': 1.0,
#    'EVENT': 0.10769230769230748,
#    'ORDINAL': 0.15384615384615358,
#    'GPE': 0.7076923076923065,
#    'PERSON': 0.9999999999999989,
#    'MONEY': 0.015384615384615363,
#    'NORP': 0.16923076923076896,
#    'QUANTITY': 0.13846153846153827,
#    'PRODUCT': 0.015384615384615363}},
#  'what angle': {'norm_ner': {'CARDINAL': 0.15789473684210487,
#    'PERSON': 1.0,
#    'DATE': 0.6842105263157894,
#    'GPE': 0.36842105263157887,
#    'FAC': 0.02631578947368421,
#    'NORP': 0.18421052631578944,
#    'TIME': 0.02631578947368421,
#    'LOC': 0.31578947368421034}},
#  'what angles': {'norm_ner': {'ORDINAL': 0.8571428571428571,
#    'QUANTITY': 0.14285714285714288,
#    'GPE': 1.0,
#    'PERSON': 0.14285714285714288,
#    'ORG': 0.14285714285714288,
#    'LAW': 0.14285714285714288,
#    'WORK_OF_ART': 0.14285714285714288,
#    'TIME': 0.14285714285714288,
#    'DATE': 0.14285714285714288}},
#  'what animal': {'norm_ner': {'PERSON': 1.0,
#    'FAC': 0.012048192771084333,
#    'MONEY': 0.012048192771084333}},
#  'what animals': {'norm_ner': {'ORG': 0.8888888888888878,
#    'TIME': 1.0,
#    'GPE': 0.6666666666666652,
#    'ORDINAL': 0.1111111111111111,
#    'FAC': 1.0}},
#  'what anime': {'norm_ner': {'ORG': 1.0,
#    'PERSON': 0.4374999999999996,
#    'WORK_OF_ART': 0.0625,
#    'GPE': 0.25000000000000006}},
#  'what anodes for salt water forum': {'norm_ner': {'DATE': 1.0,
#    'GPE': 0.125,
#    'NORP': 0.125}},
#  'what antibiotic': {'norm_ner': {'ORG': 1.0,
#    'WORK_OF_ART': 0.33333333333333337}},
#  'what antihistamines': {'norm_ner': {'PERCENT': 0.017543859649122806,
#    'CARDINAL': 0.017543859649122806,
#    'PRODUCT': 0.017543859649122806,
#    'ORG': 1.0,
#    'TIME': 0.15789473684210525}},
#  'what aor': {'norm_ner': {'CARDINAL': 0.43749999999999994,
#    'PERSON': 1.0,
#    'GPE': 0.06249999999999965,
#    'QUANTITY': 0.0625,
#    'PRODUCT': 0.0625}},
#  'what application': {'norm_ner': {'PRODUCT': 0.20769230769230754,
#    'CARDINAL': 0.0846153846153845,
#    'GPE': 0.023076923076923057,
#    'ORG': 1.0,
#    'PERSON': 0.05384615384615376,
#    'QUANTITY': 0.007692307692307687,
#    'ORDINAL': 0.007692307692307687,
#    'FAC': 0.05384615384615381,
#    'WORK_OF_ART': 0.007692307692307687,
#    'LAW': 0.007692307692307687,
#    'NORP': 0.06923076923076919,
#    'PERCENT': 0.05384615384615381}},
#  'which phase': {'norm_ner': {'GPE': 0.8888888888888888,
#    'CARDINAL': 0.4444444444444438,
#    'FAC': 0.1111111111111111,
#    'PERCENT': 1.0}},
#  'what county in utah': {'norm_ner': {'GPE': 1.0,
#    'LOC': 0.06306306306306303,
#    'QUANTITY': 0.07207207207207203,
#    'LANGUAGE': 0.009009009009009004,
#    'TIME': 0.009009009009009004,
#    'FAC': 0.009009009009009004,
#    'PRODUCT': 0.009009009009009004}},
#  'what area': {'norm_ner': {'ORG': 0.3396226415094336,
#    'GPE': 0.9245283018867988,
#    'LOC': 1.0,
#    'TIME': 0.01886792452830188,
#    'EVENT': 0.01886792452830188}},
#  'what area of the brain': {'norm_ner': {'DATE': 1.0}},
#  'what areas': {'norm_ner': {'GPE': 1.0,
#    'CARDINAL': 0.017857142857142728,
#    'ORDINAL': 0.12499999999999971,
#    'PERSON': 0.17857142857142816,
#    'LANGUAGE': 0.017857142857142818,
#    'NORP': 0.10714285714285693,
#    'PERCENT': 0.017857142857142818,
#    'LOC': 0.4285714285714276,
#    'FAC': 0.017857142857142818,
#    'PRODUCT': 0.017857142857142818}},
#  'what art style': {'norm_ner': {'NORP': 0.3157894736842104,
#    'ORG': 1.0,
#    'CARDINAL': 0.2631578947368422,
#    'LOC': 0.05263157894736844,
#    'ORDINAL': 0.05263157894736844}},
#  'what artists': {'norm_ner': {'FAC': 0.16666666666666669,
#    'ORG': 1.0,
#    'EVENT': 0.16666666666666669,
#    'ORDINAL': 0.16666666666666669}},
#  'what aspca': {'norm_ner': {'ORG': 1.0}},
#  'what aspirin': {'norm_ner': {'FAC': 1.0, 'PERSON': 1.0}},
#  'what assets': {'norm_ner': {'LOC': 0.19999999999999998,
#    'ORDINAL': 0.19999999999999998,
#    'CARDINAL': 1.0,
#    'NORP': 0.19999999999999998}},
#  'what association': {'norm_ner': {'PERSON': 0.2857142857142855,
#    'DATE': 0.31428571428571417,
#    'GPE': 0.5999999999999998,
#    'ORDINAL': 0.2285714285714285,
#    'NORP': 1.0,
#    'ORG': 0.5714285714285713,
#    'EVENT': 0.028571428571428564}},
#  'what astronomical bodies': {'norm_ner': {'ORG': 1.0,
#    'PERSON': 0.18518518518518515,
#    'PERCENT': 0.03703703703703704,
#    'GPE': 0.03703703703703704,
#    'NORP': 0.03703703703703704}},
#  'what atoms': {'norm_ner': {'ORG': 1.0,
#    'GPE': 0.14285714285714288,
#    'LAW': 0.14285714285714288,
#    'ORDINAL': 0.14285714285714288}},
#  'what authority': {'norm_ner': {'CARDINAL': 1.0, 'ORDINAL': 0.125}},
#  'what award': {'norm_ner': {'PERSON': 0.972972972972978,
#    'TIME': 0.16216216216216198,
#    'ORG': 0.621621621621621,
#    'ORDINAL': 0.027027027027026997,
#    'FAC': 0.675675675675675,
#    'GPE': 0.5135135135135129,
#    'LANGUAGE': 0.027027027027026997,
#    'CARDINAL': 1.0,
#    'PERCENT': 0.027027027027026997,
#    'NORP': 0.21621621621621598,
#    'LAW': 0.027027027027026997}},
#  'what awards': {'norm_ner': {'EVENT': 0.3599999999999993,
#    'GPE': 0.519999999999999,
#    'ORG': 0.03999999999999923,
#    'DATE': 0.8399999999999995,
#    'TIME': 0.6799999999999988,
#    'NORP': 0.3199999999999993,
#    'CARDINAL': 1.0,
#    'ORDINAL': 0.11999999999999973,
#    'MONEY': 0.03999999999999993}},
#  'what awareness month': {'norm_ner': {'DATE': 0.4444444444444445,
#    'MONEY': 0.1111111111111111,
#    'GPE': 1.0,
#    'WORK_OF_ART': 0.1111111111111111}},
#  'what axons': {'norm_ner': {'CARDINAL': 1.0,
#    'ORG': 0.16666666666666663,
#    'DATE': 0.16666666666666663}},
#  'what bank': {'norm_ner': {'DATE': 1.0,
#    'MONEY': 0.07692307692307693,
#    'NORP': 0.07692307692307693,
#    'WORK_OF_ART': 0.07692307692307693}},
#  'what base': {'norm_ner': {'MONEY': 0.1111111111111111, 'GPE': 1.0}},
#  'what baseball announcer': {'norm_ner': {'PERSON': 0.027777777777777513,
#    'GPE': 0.41666666666666663,
#    'CARDINAL': 0.027777777777777776,
#    'NORP': 1.0,
#    'DATE': 0.9722222222222221,
#    'FAC': 0.027777777777777776,
#    'LOC': 0.027777777777777776}},
#  'what battery': {'norm_ner': {'PERSON': 0.4444444444444445,
#    'DATE': 0.7777777777777777,
#    'WORK_OF_ART': 0.1111111111111111,
#    'FAC': 0.1111111111111111,
#    'LOC': 1.0,
#    'LAW': 0.1111111111111111}},
#  'what battles': {'norm_ner': {'CARDINAL': 1.0,
#    'NORP': 0.9333333333333333,
#    'WORK_OF_ART': 0.06666666666666667}},
#  'what bay': {'norm_ner': {'CARDINAL': 1.0,
#    'ORG': 0.30769230769230776,
#    'MONEY': 0.07692307692307693,
#    'EVENT': 0.07692307692307693,
#    'LOC': 0.3846153846153847,
#    'DATE': 0.07692307692307693}},
#  'what beach': {'norm_ner': {'PERSON': 0.3934426229508195,
#    'GPE': 1.0,
#    'LOC': 0.9508196721311475,
#    'QUANTITY': 0.18032786885245897,
#    'FAC': 0.34426229508196715,
#    'EVENT': 0.016393442622950817,
#    'PERCENT': 0.016393442622950817,
#    'PRODUCT': 0.016393442622950817,
#    'ORDINAL': 0.016393442622950817}},
#  'what being a graphic designer': {'norm_ner': {'CARDINAL': 1.0}},
#  'what benefits': {'norm_ner': {'ORG': 1.0,
#    'PERSON': 0.02439024390243896,
#    'CARDINAL': 0.6585365853658528,
#    'LAW': 0.46341463414634093,
#    'GPE': 0.09756097560975595,
#    'PRODUCT': 0.024390243902438994,
#    'WORK_OF_ART': 0.024390243902438994,
#    'LOC': 0.024390243902438994,
#    'NORP': 0.024390243902438994,
#    'ORDINAL': 0.21951219512195097}},
#  'what big city': {'norm_ner': {'GPE': 1.0,
#    'DATE': 0.09677419354838711,
#    'FAC': 0.03225806451612904,
#    'PERCENT': 0.03225806451612904,
#    'EVENT': 0.03225806451612904,
#    'ORDINAL': 0.03225806451612904}},
#  'what biological process': {'norm_ner': {'GPE': 1.0,
#    'FAC': 1.0,
#    'PRODUCT': 1.0}},
#  'what biome in canada': {'norm_ner': {'GPE': 0.159090909090909,
#    'ORG': 1.0,
#    'LOC': 0.3863636363636364,
#    'DATE': 0.022727272727272728,
#    'PERSON': 0.2272727272727273,
#    'WORK_OF_ART': 0.20454545454545456,
#    'FAC': 0.20454545454545456}},
#  'what birth years': {'norm_ner': {'PERSON': 0.19047619047619013,
#    'DATE': 1.0,
#    'LOC': 0.16666666666666635,
#    'EVENT': 0.38095238095238027,
#    'ORG': 0.14285714285714257,
#    'ORDINAL': 0.023809523809523767}},
#  'what bjm': {'norm_ner': {'GPE': 1.0,
#    'QUANTITY': 0.10000000000000003,
#    'NORP': 0.10000000000000003,
#    'ORDINAL': 0.10000000000000003}},
#  'what blooms in spring': {'norm_ner': {'DATE': 0.02857142857142852,
#    'CARDINAL': 1.0,
#    'PERSON': 0.12857142857142856,
#    'ORG': 0.2714285714285714,
#    'GPE': 0.08571428571428569,
#    'PERCENT': 0.014285714285714284}},
#  'what body part': {'norm_ner': {'PERCENT': 1.0, 'QUANTITY': 1.0}},
#  'what body parts': {'norm_ner': {'ORG': 0.6666666666666663,
#    'LAW': 1.0,
#    'DATE': 0.1111111111111111}},
#  'what body systems': {'norm_ner': {'WORK_OF_ART': 1.0, 'PRODUCT': 1.0}},
#  'what book': {'norm_ner': {'ORG': 0.145833333333333,
#    'DATE': 0.20833333333333318,
#    'CARDINAL': 0.1874999999999999,
#    'PERSON': 0.22916666666666607,
#    'EVENT': 0.14583333333333326,
#    'NORP': 0.4374999999999998,
#    'LAW': 0.020833333333333322,
#    'WORK_OF_ART': 1.0,
#    'FAC': 0.020833333333333322,
#    'LOC': 0.020833333333333322,
#    'MONEY': 0.0208333333333333,
#    'LANGUAGE': 0.16666666666666657}},
#  'what books': {'norm_ner': {'CARDINAL': 0.12499999999999956,
#    'TIME': 1.0,
#    'WORK_OF_ART': 0.49999999999999983,
#    'MONEY': 0.125,
#    'GPE': 0.125,
#    'LOC': 0.125}},
#  'what branch': {'norm_ner': {'GPE': 1.0,
#    'FAC': 0.052631578947368425,
#    'PRODUCT': 0.5263157894736843,
#    'PERCENT': 0.052631578947368425,
#    'LOC': 0.5263157894736843,
#    'TIME': 0.26315789473684204}},
#  'what branch of gov': {'norm_ner': {'ORG': 1.0,
#    'LOC': 0.09090909090909097,
#    'PERSON': 0.9090909090909097,
#    'DATE': 0.09090909090909097}},
#  'what branch of government': {'norm_ner': {'GPE': 1.0,
#    'LAW': 1.0,
#    'PRODUCT': 1.0,
#    'QUANTITY': 0.125}},
#  'what breed': {'norm_ner': {'ORG': 0.03999999999999996,
#    'NORP': 0.4,
#    'GPE': 1.0,
#    'PERCENT': 0.04,
#    'DATE': 0.36,
#    'LOC': 0.04}},
#  'what breed of dog': {'norm_ner': {'ORG': 1.0,
#    'DATE': 0.2580645161290323,
#    'PRODUCT': 0.2580645161290323,
#    'FAC': 0.29032258064516137,
#    'GPE': 0.12903225806451618,
#    'PERSON': 0.32258064516129004,
#    'WORK_OF_ART': 0.03225806451612904,
#    'LOC': 0.03225806451612904}},
#  'what breeds of chickens': {'norm_ner': {'PERSON': 0.38888888888888884,
#    'ORG': 1.0}},
#  'what brewers': {'norm_ner': {'DATE': 1.0,
#    'EVENT': 0.125,
#    'ORDINAL': 0.125,
#    'QUANTITY': 0.125}},
#  'what business': {'norm_ner': {'GPE': 1.0,
#    'DATE': 0.1999999999999996,
#    'PRODUCT': 0.10000000000000007,
#    'FAC': 0.8000000000000006,
#    'NORP': 0.8000000000000006,
#    'WORK_OF_ART': 0.10000000000000007,
#    'PERCENT': 0.10000000000000007}},
#  'what button': {'norm_ner': {'NORP': 0.38461538461538447,
#    'TIME': 0.010989010989010985,
#    'EVENT': 0.010989010989010985,
#    'PERSON': 0.16483516483516478,
#    'DATE': 0.010989010989010985,
#    'PRODUCT': 0.09890109890109887,
#    'FAC': 0.08791208791208788,
#    'MONEY': 0.010989010989010985,
#    'ORG': 1.0}},
#  'what camera': {'norm_ner': {'ORDINAL': 0.1111111111111111,
#    'PRODUCT': 0.1111111111111111,
#    'MONEY': 1.0,
#    'FAC': 0.1111111111111111}},
#  'what cancers': {'norm_ner': {'ORG': 0.21951219512195097, 'CARDINAL': 1.0}},
#  'what car body': {'norm_ner': {'ORG': 1.0,
#    'PRODUCT': 0.31249999999999917,
#    'PERSON': 0.9374999999999986}},
#  'what car class': {'norm_ner': {'PERSON': 1.0,
#    'DATE': 0.17777777777777767,
#    'GPE': 0.06666666666666665,
#    'PRODUCT': 0.5333333333333331,
#    'ORDINAL': 0.022222222222222213,
#    'TIME': 0.022222222222222213,
#    'QUANTITY': 0.5999999999999998}},
#  'what car': {'norm_ner': {'ORG': 1.0,
#    'CARDINAL': 0.03571428571428526,
#    'PRODUCT': 0.49999999999999994,
#    'LOC': 0.03571428571428572,
#    'PERCENT': 0.03571428571428572,
#    'ORDINAL': 0.3928571428571429}},
#  'what cars': {'norm_ner': {'ORG': 1.0,
#    'PERCENT': 0.1393442622950818,
#    'WORK_OF_ART': 0.0081967213114754,
#    'PRODUCT': 0.0655737704918032}},
#  'what cause a stroke': {'norm_ner': {'CARDINAL': 1.0,
#    'GPE': 0.08333333333333334,
#    'DATE': 0.08333333333333334,
#    'PERSON': 0.08333333333333334,
#    'TIME': 0.08333333333333334,
#    'ORDINAL': 0.08333333333333334}},
#  'what cause dizziness mayo clinic': {'norm_ner': {'GPE': 0.2500000000000001,
#    'PERCENT': 0.4166666666666668,
#    'CARDINAL': 1.0,
#    'TIME': 0.04166666666666667,
#    'PERSON': 0.12500000000000006,
#    'DATE': 0.04166666666666667}},
#  'what cause': {'norm_ner': {'CARDINAL': 0.9999999999999991,
#    'PERSON': 1.0,
#    'NORP': 0.5833333333333333,
#    'PERCENT': 0.8333333333333334,
#    'TIME': 0.08333333333333333}},
#  'what cell': {'norm_ner': {'ORG': 0.4117647058823524,
#    'PRODUCT': 0.058823529411764705,
#    'PERSON': 0.058823529411764705,
#    'PERCENT': 0.4117647058823529,
#    'CARDINAL': 0.41176470588235264,
#    'QUANTITY': 1.0,
#    'TIME': 0.5294117647058824,
#    'ORDINAL': 0.058823529411764705}},
#  'what cell process': {'norm_ner': {'NORP': 0.01818181818181818,
#    'ORG': 1.0,
#    'WORK_OF_ART': 0.01818181818181818,
#    'ORDINAL': 0.01818181818181818}},
#  'what cells': {'norm_ner': {'PERSON': 1.0,
#    'ORG': 0.6666666666666664,
#    'MONEY': 0.025641025641025637,
#    'ORDINAL': 0.025641025641025637}},
#  'what century': {'norm_ner': {'PERSON': 0.3428571428571436,
#    'ORG': 0.9142857142857147,
#    'DATE': 1.0,
#    'NORP': 0.8285714285714286,
#    'GPE': 0.22857142857142806,
#    'FAC': 0.20000000000000004,
#    'LAW': 0.02857142857142858,
#    'ORDINAL': 0.4571428571428573,
#    'QUANTITY': 0.22857142857142865}},
#  'what challenges': {'norm_ner': {'PERSON': 0.5,
#    'LOC': 0.6428571428571429,
#    'GPE': 0.35714285714285704,
#    'CARDINAL': 1.0,
#    'ORG': 0.14285714285714277,
#    'PRODUCT': 0.6428571428571429,
#    'NORP': 0.07142857142857144,
#    'PERCENT': 0.07142857142857144,
#    'MONEY': 0.07142857142857144,
#    'TIME': 0.07142857142857144,
#    'ORDINAL': 0.07142857142857144}},
#  'what change in a vein': {'norm_ner': {'PRODUCT': 1.0, 'DATE': 1.0}},
#  'what channel': {'norm_ner': {'EVENT': 0.05022831050228286,
#    'DATE': 1.0,
#    'PERSON': 0.5342465753424657,
#    'ORG': 0.9178082191780879,
#    'LAW': 0.031963470319634577,
#    'FAC': 0.12785388127853828,
#    'ORDINAL': 0.054794520547944946,
#    'QUANTITY': 0.009132420091324159,
#    'PERCENT': 0.0776255707762554,
#    'LANGUAGE': 0.06392694063926915}},
#  'what channel for sounders game': {'norm_ner': {'PERSON': 0.12499999999999983,
#    'ORG': 1.0,
#    'PRODUCT': 0.017857142857142842,
#    'NORP': 0.12499999999999989,
#    'GPE': 0.01785714285714285,
#    'TIME': 0.46428571428571386,
#    'WORK_OF_ART': 0.1607142857142856,
#    'CARDINAL': 0.6071428571428567}},
#  'what chapter of bankruptcy': {'norm_ner': {'PERCENT': 0.20000000000000007,
#    'CARDINAL': 1.0,
#    'DATE': 1.0,
#    'ORG': 0.20000000000000007}},
#  'what character': {'norm_ner': {'PERSON': 1.0,
#    'PRODUCT': 0.03278688524590149,
#    'DATE': 0.5573770491803257,
#    'NORP': 0.09836065573770446}},
#  'what characteristic best describes enriched grain products': {'norm_ner': {'EVENT': 1.0,
#    'DATE': 1.0,
#    'GPE': 1.0}},
#  'what characteristics': {'norm_ner': {'ORDINAL': 0.11111111111111116,
#    'ORG': 1.0,
#    'PRODUCT': 0.11111111111111116,
#    'PERCENT': 0.11111111111111116,
#    'WORK_OF_ART': 0.11111111111111116}},
#  'what charge': {'norm_ner': {'NORP': 1.0,
#    'PERSON': 1.0,
#    'FAC': 1.0,
#    'MONEY': 1.0,
#    'DATE': 1.0}},
#  'what cheese pairs with apricot': {'norm_ner': {'EVENT': 0.1111111111111111,
#    'PERSON': 0.5555555555555549,
#    'PRODUCT': 1.0,
#    'NORP': 0.11111111111111094,
#    'ORDINAL': 0.1111111111111111,
#    'TIME': 0.1111111111111111}},
#  'what cheeses': {'norm_ner': {'PERSON': 0.7777777777777777,
#    'NORP': 0.22222222222222204,
#    'QUANTITY': 0.22222222222222204,
#    'ORG': 0.7777777777777777,
#    'PERCENT': 1.0,
#    'FAC': 0.1111111111111111,
#    'LANGUAGE': 0.1111111111111111}},
#  'what chinese': {'norm_ner': {'LANGUAGE': 1.0,
#    'GPE': 0.750000000000002,
#    'ORG': 0.1249999999999999}},
#  'what chromosome': {'norm_ner': {'ORG': 0.1538461538461535,
#    'CARDINAL': 1.0,
#    'DATE': 0.07692307692307696,
#    'GPE': 0.07692307692307696}},
#  'what church': {'norm_ner': {'ORG': 1.0,
#    'GPE': 0.38888888888888873,
#    'EVENT': 0.44444444444444453,
#    'TIME': 0.055555555555555566}},
#  'what cities': {'norm_ner': {'GPE': 1.0,
#    'CARDINAL': 0.29444444444444373,
#    'LOC': 0.17777777777777737,
#    'WORK_OF_ART': 0.04999999999999989,
#    'DATE': 0.14999999999999972,
#    'ORDINAL': 0.011111111111111079,
#    'NORP': 0.07222222222222204,
#    'LANGUAGE': 0.005555555555555544}},
#  'what city': {'norm_ner': {'ORG': 0.4871794871795024,
#    'FAC': 0.02403846153846205,
#    'GPE': 1.0,
#    'PERSON': 0.26442307692308487,
#    'NORP': 0.017628205128205475,
#    'EVENT': 0.044871794871795906,
#    'QUANTITY': 0.027243589743590337,
#    'PRODUCT': 0.016025641025641378,
#    'ORDINAL': 0.056089743589745035,
#    'LOC': 0.10576923076923336}},
#  'what city in oregon': {'norm_ner': {'CARDINAL': 0.6799999999999982,
#    'GPE': 1.0,
#    'PERCENT': 0.35999999999999915,
#    'MONEY': 0.35999999999999915,
#    'ORDINAL': 0.19999999999999946}},
#  'what civil rights unrest': {'norm_ner': {'PERSON': 0.9687500000000008,
#    'DATE': 1.0,
#    'ORG': 0.6249999999999999,
#    'PRODUCT': 0.03125,
#    'GPE': 0.84375,
#    'LAW': 0.31250000000000006,
#    'NORP': 0.03125,
#    'LOC': 0.28125,
#    'ORDINAL': 0.03125,
#    'WORK_OF_ART': 0.03125}},
#  'what class': {'norm_ner': {'PERSON': 1.0,
#    'NORP': 0.5599999999999998,
#    'ORG': 0.27999999999999864,
#    'GPE': 0.39999999999999936,
#    'ORDINAL': 0.040000000000000015,
#    'PERCENT': 0.039999999999999994,
#    'MONEY': 0.039999999999999994,
#    'LAW': 0.039999999999999994,
#    'QUANTITY': 0.039999999999999994}},
#  'what classes': {'norm_ner': {'ORDINAL': 0.35294117647058815,
#    'WORK_OF_ART': 0.47058823529411764,
#    'ORG': 0.5294117647058817,
#    'PERSON': 0.11764705882352941,
#    'PERCENT': 0.058823529411764705,
#    'GPE': 1.0,
#    'MONEY': 0.058823529411764705,
#    'EVENT': 0.058823529411764705}},
#  'what code': {'norm_ner': {'NORP': 0.5714285714285712,
#    'DATE': 1.0,
#    'ORG': 0.28571428571428525,
#    'LAW': 0.047619047619047616,
#    'CARDINAL': 0.6666666666666664,
#    'PERCENT': 0.047619047619047616,
#    'PRODUCT': 0.047619047619047616,
#    'TIME': 0.047619047619047616,
#    'FAC': 0.42857142857142855}},
#  'what college': {'norm_ner': {'PERSON': 0.5285714285714286,
#    'DATE': 0.21428571428571372,
#    'ORG': 0.05714285714285685,
#    'GPE': 1.0,
#    'NORP': 0.042857142857142795,
#    'FAC': 0.014285714285714268,
#    'LANGUAGE': 0.014285714285714268,
#    'ORDINAL': 0.14285714285714263,
#    'PRODUCT': 0.08571428571428559,
#    'TIME': 0.25714285714285684}},
#  'what colony': {'norm_ner': {'CARDINAL': 0.4705882352941173,
#    'GPE': 1.0,
#    'ORG': 0.5588235294117643,
#    'PERSON': 0.44117647058823484,
#    'LOC': 0.23529411764705863,
#    'NORP': 0.08823529411764701,
#    'PERCENT': 0.02941176470588233,
#    'EVENT': 0.02941176470588233,
#    'WORK_OF_ART': 0.02941176470588233}},
#  'what color': {'norm_ner': {'NORP': 1.0,
#    'PERSON': 0.017857142857142027,
#    'QUANTITY': 0.14285714285714263,
#    'DATE': 0.8392857142857144,
#    'LOC': 0.6428571428571421,
#    'GPE': 0.5535714285714325,
#    'PERCENT': 0.24999999999999972,
#    'FAC': 0.03571428571428565}},
#  'what color corrector': {'norm_ner': {'LOC': 0.125, 'PERSON': 1.0}},
#  'what color dress': {'norm_ner': {'NORP': 1.0,
#    'GPE': 0.20000000000000007,
#    'EVENT': 0.20000000000000007}},
#  'what color flame': {'norm_ner': {'ORG': 0.2962962962962963,
#    'ORDINAL': 0.3333333333333333,
#    'CARDINAL': 0.4814814814814814,
#    'PERSON': 1.0,
#    'EVENT': 0.037037037037037035}},
#  'what color light': {'norm_ner': {'CARDINAL': 1.0}},
#  'what colors': {'norm_ner': {'CARDINAL': 0.7368421052631592,
#    'PERSON': 1.0,
#    'TIME': 0.4210526315789475,
#    'LAW': 0.05263157894736844,
#    'EVENT': 0.05263157894736844,
#    'LANGUAGE': 0.05263157894736844}},
#  'what colour': {'norm_ner': {'GPE': 0.157894736842105,
#    'CARDINAL': 0.894736842105263,
#    'QUANTITY': 1.0,
#    'PRODUCT': 0.368421052631579,
#    'PERSON': 0.8421052631578957,
#    'NORP': 0.052631578947368425,
#    'LOC': 0.5263157894736841,
#    'FAC': 0.052631578947368425}},
#  'what combines tissue to make organism': {'norm_ner': {'GPE': 1.0}},
#  'what committees': {'norm_ner': {'QUANTITY': 0.14285714285714288,
#    'ORG': 0.14285714285714152,
#    'DATE': 0.285714285714285,
#    'LOC': 1.0,
#    'CARDINAL': 0.14285714285714288}},
#  'what companies': {'norm_ner': {'ORG': 1.0,
#    'LAW': 0.028571428571428515,
#    'NORP': 0.08571428571428566,
#    'GPE': 0.2571428571428568,
#    'WORK_OF_ART': 0.028571428571428557,
#    'QUANTITY': 0.028571428571428557,
#    'FAC': 0.028571428571428557,
#    'MONEY': 0.028571428571428557,
#    'PERCENT': 0.028571428571428557,
#    'LOC': 0.6571428571428568}},
#  'what company streams': {'norm_ner': {'ORDINAL': 0.037037037037037035,
#    'PERSON': 0.25925925925925924,
#    'CARDINAL': 1.0,
#    'MONEY': 0.037037037037037035,
#    'QUANTITY': 0.037037037037037035}},
#  'what compensation': {'norm_ner': {'FAC': 0.06666666666666667,
#    'ORG': 0.4666666666666665,
#    'CARDINAL': 0.4666666666666667,
#    'DATE': 1.0,
#    'GPE': 0.8,
#    'ORDINAL': 0.06666666666666667,
#    'LOC': 0.06666666666666667,
#    'WORK_OF_ART': 0.06666666666666667,
#    'TIME': 0.5333333333333333}},
#  'what conclusions': {'norm_ner': {'LOC': 0.8125000000000001,
#    'PERSON': 1.0,
#    'NORP': 0.3750000000000001,
#    'ORG': 0.12499999999999997,
#    'PRODUCT': 0.06250000000000003,
#    'GPE': 0.06250000000000003,
#    'QUANTITY': 0.06250000000000003,
#    'TIME': 0.06250000000000003,
#    'FAC': 0.06250000000000003}},
#  'what condition': {'norm_ner': {'LAW': 0.16666666666666669, 'LOC': 1.0}},
#  'what conditions': {'norm_ner': {'PRODUCT': 1.0,
#    'ORDINAL': 0.2500000000000001,
#    'DATE': 0.2500000000000001}},
#  'what ethnicity': {'norm_ner': {'NORP': 1.0,
#    'GPE': 0.12389380530973435,
#    'LOC': 0.07079646017699108,
#    'PERSON': 0.35398230088495586,
#    'ORG': 0.15929203539822984,
#    'LANGUAGE': 0.061946902654867186,
#    'FAC': 0.008849557522123885,
#    'PERCENT': 0.15929203539822992}},
#  'what conference': {'norm_ner': {'ORG': 0.8333333333333354,
#    'GPE': 0.06666666666666649,
#    'NORP': 1.0,
#    'CARDINAL': 0.4666666666666665,
#    'WORK_OF_ART': 0.03333333333333333,
#    'QUANTITY': 0.33333333333333337,
#    'PERCENT': 0.03333333333333333,
#    'MONEY': 0.03333333333333333}},
#  'what congressmen': {'norm_ner': {'MONEY': 0.3181818181818183,
#    'ORG': 1.0,
#    'NORP': 0.36363636363636376,
#    'DATE': 0.7272727272727275,
#    'PERCENT': 0.04545454545454547}},
#  'what connection': {'norm_ner': {'NORP': 1.0}},
#  'what connective tissue cell type': {'norm_ner': {'NORP': 1.0}},
#  'what constitutional clause': {'norm_ner': {'LAW': 0.7999999999999996,
#    'GPE': 1.0,
#    'PERSON': 0.19999999999999998}},
#  'what continent': {'norm_ner': {'LOC': 0.4705882352941178,
#    'QUANTITY': 0.05347593582887689,
#    'DATE': 0.11764705882352919,
#    'ORG': 0.26203208556149754,
#    'NORP': 0.03743315508021379,
#    'CARDINAL': 0.2513368983957222,
#    'GPE': 1.0,
#    'ORDINAL': 0.06951871657753997,
#    'WORK_OF_ART': 0.005347593582887691,
#    'PERCENT': 0.1122994652406415}},
#  'what continents': {'norm_ner': {'DATE': 0.16541353383458643,
#    'TIME': 0.007518796992481201,
#    'CARDINAL': 0.4060150375939853,
#    'GPE': 1.0,
#    'ORG': 0.08270676691729321,
#    'QUANTITY': 0.14285714285714285,
#    'PRODUCT': 0.12781954887218042,
#    'ORDINAL': 0.007518796992481201}},
#  'what contribution': {'norm_ner': {'ORG': 0.42857142857142855,
#    'PERSON': 0.4999999999999997,
#    'ORDINAL': 1.0,
#    'LANGUAGE': 0.07142857142857144,
#    'NORP': 0.07142857142857144}},
#  'what controller': {'norm_ner': {'ORG': 0.6666666666666665,
#    'NORP': 1.0,
#    'PERSON': 0.5555555555555556,
#    'LOC': 1.0}},
#  'what controls': {'norm_ner': {'ORDINAL': 1.0, 'QUANTITY': 1.0, 'ORG': 1.0}},
#  'what costs': {'norm_ner': {'CARDINAL': 1.0, 'GPE': 1.0}},
#  'what costume style': {'norm_ner': {'GPE': 1.0,
#    'LOC': 0.3478260869565218,
#    'EVENT': 0.04347826086956522,
#    'LANGUAGE': 0.04347826086956522,
#    'ORDINAL': 0.04347826086956522}},
#  'what counts as liquids for tsa': {'norm_ner': {'CARDINAL': 0.4999999999999999,
#    'ORG': 1.0,
#    'QUANTITY': 0.05,
#    'NORP': 0.05}},
#  'what county brisbane': {'norm_ner': {'ORG': 1.0,
#    'GPE': 0.5294117647058814,
#    'CARDINAL': 0.6470588235294105,
#    'NORP': 0.5294117647058816,
#    'MONEY': 0.5294117647058816,
#    'EVENT': 0.05882352941176462,
#    'PERSON': 0.05882352941176462}},
#  'what county frytown iowa': {'norm_ner': {'PRODUCT': 0.09090909090909091,
#    'GPE': 1.0,
#    'FAC': 0.8181818181818181,
#    'CARDINAL': 0.09090909090909091,
#    'MONEY': 0.09090909090909091}},
#  'what county hurricane wv': {'norm_ner': {'GPE': 1.0,
#    'CARDINAL': 0.6428571428571426,
#    'EVENT': 0.7142857142857145,
#    'WORK_OF_ART': 0.7142857142857145,
#    'PERSON': 0.07142857142857144,
#    'ORDINAL': 0.07142857142857144,
#    'TIME': 0.07142857142857144}},
#  'what county in huntington in in': {'norm_ner': {'ORG': 0.4166666666666659,
#    'GPE': 1.0,
#    'PERSON': 0.0416666666666666,
#    'PERCENT': 0.0416666666666666,
#    'PRODUCT': 0.0416666666666666}},
#  'what county in nc': {'norm_ner': {'QUANTITY': 1.0,
#    'ORG': 0.043478260869565154,
#    'GPE': 0.17391304347826028,
#    'LOC': 0.6521739130434783,
#    'FAC': 0.3043478260869565}},
#  'what county in pa': {'norm_ner': {'ORG': 1.0,
#    'ORDINAL': 0.10000000000000003,
#    'WORK_OF_ART': 0.10000000000000003,
#    'NORP': 0.10000000000000003,
#    'TIME': 0.10000000000000003}},
#  'what county in tn collinwood': {'norm_ner': {'ORG': 0.2653061224489794,
#    'GPE': 1.0,
#    'QUANTITY': 0.1632653061224489}},
#  'what county in tn elizabethton': {'norm_ner': {'DATE': 0.30000000000000004,
#    'PERSON': 1.0,
#    'PRODUCT': 0.049999999999999996,
#    'ORG': 0.7999999999999999,
#    'NORP': 0.049999999999999996,
#    'ORDINAL': 0.049999999999999996,
#    'TIME': 0.049999999999999996}},
#  'what county in tn manchester': {'norm_ner': {'GPE': 1.0,
#    'CARDINAL': 0.4857142857142846,
#    'TIME': 0.02857142857142851,
#    'ORDINAL': 0.2571428571428566,
#    'NORP': 0.2571428571428566,
#    'WORK_OF_ART': 0.02857142857142851}},
#  'what county in tn summertown': {'norm_ner': {'CARDINAL': 0.3055555555555555,
#    'GPE': 0.6111111111111109,
#    'PERSON': 1.0,
#    'DATE': 0.25}},
#  'how many weight watchers': {'norm_ner': {'PERSON': 1.0,
#    'PRODUCT': 0.5333333333333335,
#    'NORP': 0.0666666666666667}},
#  'what county roy wa': {'norm_ner': {'ORDINAL': 0.02857142857142857,
#    'QUANTITY': 0.45714285714285713,
#    'CARDINAL': 0.08571428571428573,
#    'FAC': 0.02857142857142857,
#    'MONEY': 0.22857142857142856,
#    'PERSON': 0.9714285714285719,
#    'DATE': 1.0,
#    'WORK_OF_ART': 0.02857142857142857,
#    'PERCENT': 1.0}},
#  'what courses': {'norm_ner': {'ORG': 0.47368421052631504,
#    'PERCENT': 0.052631578947368425,
#    'DATE': 0.631578947368421,
#    'MONEY': 0.36842105263157904,
#    'GPE': 1.0,
#    'NORP': 0.4210526315789474,
#    'PERSON': 0.8421052631578948,
#    'WORK_OF_ART': 0.052631578947368425,
#    'EVENT': 0.4736842105263159}},
#  'what court': {'norm_ner': {'GPE': 1.0,
#    'WORK_OF_ART': 0.07142857142857145,
#    'ORDINAL': 0.3571428571428573,
#    'MONEY': 0.07142857142857145,
#    'DATE': 0.7142857142857143,
#    'LAW': 0.35714285714285715,
#    'PERCENT': 0.07142857142857145,
#    'PERSON': 0.7142857142857137,
#    'TIME': 0.6428571428571431,
#    'NORP': 0.07142857142857145}},
#  'what covers': {'norm_ner': {'ORG': 1.0, 'DATE': 1.0, 'NORP': 1.0}},
#  'what credit score': {'norm_ner': {'CARDINAL': 1.0,
#    'GPE': 0.4285714285714283,
#    'ORG': 0.48571428571428515,
#    'FAC': 0.028571428571428557,
#    'EVENT': 0.22857142857142845,
#    'PRODUCT': 0.028571428571428557}},
#  'what cricut cartridge': {'norm_ner': {'ORG': 1.0,
#    'LOC': 0.2903225806451611,
#    'DATE': 0.8709677419354832,
#    'TIME': 0.03225806451612901,
#    'NORP': 0.03225806451612901,
#    'MONEY': 0.03225806451612901}},
#  'what crimes': {'norm_ner': {'DATE': 0.49999999999999933,
#    'EVENT': 0.9999999999999997,
#    'GPE': 1.0,
#    'NORP': 0.16666666666666663,
#    'WORK_OF_ART': 0.16666666666666663,
#    'ORDINAL': 0.16666666666666663}},
#  'what criteria': {'norm_ner': {'CARDINAL': 1.0, 'NORP': 0.03333333333333334}},
#  'what cruise ships': {'norm_ner': {'DATE': 1.0,
#    'PERSON': 0.39999999999999947,
#    'GPE': 0.749999999999999,
#    'PRODUCT': 0.44999999999999946}},
#  'what crypto': {'norm_ner': {'PERSON': 0.40000000000000013,
#    'ORG': 1.0,
#    'PERCENT': 0.10000000000000007,
#    'NORP': 0.10000000000000007}},
#  'what culture': {'norm_ner': {'CARDINAL': 0.8571428571428571,
#    'ORG': 1.0,
#    'GPE': 0.7142857142857139,
#    'PRODUCT': 0.07142857142857144}},
#  'what currency': {'norm_ner': {'NORP': 1.0,
#    'CARDINAL': 0.7435897435897434,
#    'GPE': 0.7948717948717989,
#    'DATE': 0.8974358974358978,
#    'LANGUAGE': 0.9230769230769222,
#    'MONEY': 0.28205128205128155,
#    'FAC': 0.07692307692307686,
#    'PRODUCT': 0.20512820512820493,
#    'LAW': 0.20512820512820493,
#    'WORK_OF_ART': 0.025641025641025616}},
#  'what date': {'norm_ner': {'DATE': 1.0,
#    'EVENT': 0.627118644067792,
#    'LANGUAGE': 0.016949152542372767,
#    'FAC': 0.10169491525423648,
# ...
#    'PERSON': 0.8888888888888888,
#    'FAC': 1.0,
#    'GPE': 0.1111111111111111,
#    'PRODUCT': 0.1111111111111111}},
#  'what type of gorilla': {'norm_ner': {'PERSON': 0.37499999999999994,
#    'DATE': 0.9375,
#    'ORG': 0.6249999999999998,
#    'FAC': 0.0625,
#    'WORK_OF_ART': 0.0625,
#    'NORP': 0.0625,
#    'GPE': 1.0,
#    'MONEY': 0.0625,
#    'TIME': 0.0625}},
#  'what type of government': {'norm_ner': {'DATE': 0.14864864864864674,
#    'ORG': 0.7702702702702765,
#    'PERSON': 1.0,
#    'MONEY': 0.43243243243242935,
#    'GPE': 0.797297297297304,
#    'NORP': 0.16216216216216106,
#    'EVENT': 0.09459459459459373,
#    'FAC': 0.24324324324324112,
#    'QUANTITY': 0.29729729729729465}},
#  'what type of hat': {'norm_ner': {'LOC': 1.0,
#    'PERCENT': 0.14285714285714288,
#    'LANGUAGE': 0.14285714285714288}},
#  'what type of header': {'norm_ner': {'DATE': 0.06666666666666667,
#    'QUANTITY': 1.0,
#    'NORP': 0.06666666666666667,
#    'WORK_OF_ART': 0.06666666666666667}},
#  'what type of industry': {'norm_ner': {'CARDINAL': 0.2692307692307693,
#    'DATE': 0.15384615384615385,
#    'ORG': 1.0,
#    'ORDINAL': 0.038461538461538464,
#    'MONEY': 0.038461538461538464,
#    'PRODUCT': 0.038461538461538464,
#    'PERSON': 0.038461538461538464,
#    'FAC': 0.038461538461538464,
#    'PERCENT': 0.038461538461538464,
#    'NORP': 0.3846153846153847}},
#  'what type of inheritance': {'norm_ner': {'CARDINAL': 0.6666666666666661,
#    'PRODUCT': 1.0,
#    'NORP': 0.1111111111111111}},
#  'what type of insulation and drywall for basement': {'norm_ner': {'GPE': 1.0,
#    'NORP': 1.0}},
#  'what type of kids': {'norm_ner': {'NORP': 1.0, 'ORG': 1.0}},
#  'what type of liens': {'norm_ner': {'ORG': 1.0}},
#  'what type of malware': {'norm_ner': {'ORG': 0.7999999999999992,
#    'ORDINAL': 0.7999999999999999,
#    'DATE': 0.7999999999999999,
#    'PRODUCT': 0.09999999999999999,
#    'GPE': 1.0,
#    'TIME': 0.09999999999999999}},
#  'what type of material': {'norm_ner': {'PERSON': 0.5999999999999991,
#    'DATE': 1.0}},
#  'what type of material used in cooling system': {'norm_ner': {'WORK_OF_ART': 0.08333333333333334,
#    'CARDINAL': 1.0,
#    'DATE': 0.7500000000000002,
#    'PERSON': 0.33333333333333326,
#    'NORP': 0.6666666666666667,
#    'LAW': 0.08333333333333334,
#    'PERCENT': 0.08333333333333334,
#    'PRODUCT': 0.08333333333333334}},
#  'what type of measurements': {'norm_ner': {'ORG': 1.0,
#    'TIME': 0.5000000000000003,
#    'PERCENT': 0.5000000000000003,
#    'PRODUCT': 0.5000000000000003}},
#  'what type of medication': {'norm_ner': {'PERSON': 1.0,
#    'NORP': 0.3333333333333329,
#    'FAC': 0.023809523809523784,
#    'DATE': 0.7380952380952372,
#    'QUANTITY': 0.023809523809523784,
#    'ORDINAL': 0.4047619047619043,
#    'WORK_OF_ART': 0.023809523809523784}},
#  'what type of medicine': {'norm_ner': {'CARDINAL': 1.0,
#    'ORG': 0.34090909090909005,
#    'GPE': 0.5909090909090926,
#    'LANGUAGE': 0.0227272727272727,
#    'LOC': 0.3636363636363632,
#    'QUANTITY': 0.7272727272727264,
#    'PRODUCT': 0.3636363636363632,
#    'PERCENT': 0.0227272727272727,
#    'ORDINAL': 0.7045454545454538}},
#  'what type of membrane lines cavities that open to the outside of the body': {'norm_ner': {'NORP': 1.0,
#    'ORG': 1.0,
#    'PERSON': 1.0,
#    'LANGUAGE': 1.0}},
#  'what type of metal': {'norm_ner': {'ORG': 1.0,
#    'GPE': 0.14285714285714265,
#    'PERSON': 0.8571428571428565,
#    'ORDINAL': 0.17142857142857126,
#    'DATE': 0.9999999999999998,
#    'LOC': 0.25714285714285695,
#    'PRODUCT': 0.25714285714285695,
#    'FAC': 0.2285714285714284,
#    'WORK_OF_ART': 0.25714285714285695,
#    'TIME': 0.02857142857142855}},
#  'what type of mollusk': {'norm_ner': {'CARDINAL': 1.0,
#    'DATE': 0.24999999999999997,
#    'ORDINAL': 0.24999999999999997}},
#  'what type of mt.': {'norm_ner': {'NORP': 1.0}},
#  'what type of nutrient': {'norm_ner': {'DATE': 1.0, 'TIME': 1.0}},
#  'what type of oil': {'norm_ner': {'DATE': 1.0,
#    'QUANTITY': 0.024999999999999998,
#    'PRODUCT': 0.19999999999999998,
#    'PERSON': 0.024999999999999998}},
#  'what type of plywood for tile': {'norm_ner': {'ORG': 1.0}},
#  'what type of projects': {'norm_ner': {'ORG': 0.9999999999999905,
#    'GPE': 1.0}},
#  'what type of protein': {'norm_ner': {'FAC': 0.029411764705882356,
#    'ORG': 1.0,
#    'GPE': 0.8823529411764707,
#    'QUANTITY': 0.029411764705882356,
#    'LOC': 0.17647058823529416,
#    'WORK_OF_ART': 0.20588235294117646,
#    'MONEY': 0.14705882352941174,
#    'TIME': 0.029411764705882356,
#    'PERCENT': 0.029411764705882356}},
#  'what type of radiation': {'norm_ner': {'ORG': 0.06557377049180305,
#    'CARDINAL': 0.01639344262295068,
#    'PRODUCT': 0.0163934426229508,
#    'GPE': 1.0,
#    'QUANTITY': 0.1475409836065572,
#    'DATE': 0.049180327868852375,
#    'NORP': 0.049180327868852375,
#    'WORK_OF_ART': 0.0163934426229508}},
#  'what type of responsibility': {'norm_ner': {'PERSON': 1.0, 'CARDINAL': 1.0}},
#  'what type of seating': {'norm_ner': {'ORG': 0.2222222222222216,
#    'PRODUCT': 1.0,
#    'WORK_OF_ART': 0.7777777777777777,
#    'MONEY': 0.1111111111111111,
#    'ORDINAL': 0.1111111111111111,
#    'FAC': 0.1111111111111111}},
#  'what type of security': {'norm_ner': {'TIME': 1.0, 'FAC': 1.0}},
#  'what type of services': {'norm_ner': {'LAW': 0.17647058823529413,
#    'DATE': 0.5,
#    'PERSON': 1.0,
#    'PRODUCT': 0.029411764705882353,
#    'ORDINAL': 0.2647058823529412}},
#  'what type of soil': {'norm_ner': {'DATE': 0.5208333333333331,
#    'ORG': 0.0625,
#    'NORP': 0.02083333333333333,
#    'PERSON': 1.0,
#    'WORK_OF_ART': 0.02083333333333333}},
#  'what type of species': {'norm_ner': {'GPE': 0.35294117647058826,
#    'PERSON': 0.9411764705882353,
#    'LOC': 0.47058823529411764,
#    'QUANTITY': 0.5882352941176471,
#    'CARDINAL': 1.0}},
#  'what type of structure': {'norm_ner': {'CARDINAL': 1.0,
#    'PRODUCT': 0.06250000000000001}},
#  'what type of stuff': {'norm_ner': {'ORG': 0.8571428571428571,
#    'DATE': 1.0,
#    'NORP': 0.6428571428571427,
#    'CARDINAL': 0.07142857142857144}},
#  'what type of test': {'norm_ner': {'ORG': 1.0,
#    'PERCENT': 0.16666666666666674,
#    'LAW': 0.16666666666666674,
#    'TIME': 0.16666666666666674,
#    'QUANTITY': 0.16666666666666674}},
#  'what type of thermometer': {'norm_ner': {'ORDINAL': 1.0,
#    'CARDINAL': 1.0,
#    'ORG': 1.0,
#    'PERSON': 1.0}},
#  'what type of thinset for fiba tape': {'norm_ner': {'ORG': 1.0,
#    'TIME': 0.08333333333333334,
#    'QUANTITY': 0.08333333333333334}},
#  'what type of tissue': {'norm_ner': {'CARDINAL': 0.6603773584905642,
#    'GPE': 0.3396226415094331,
#    'QUANTITY': 0.11320754716981088,
#    'LOC': 0.30188679245282896,
#    'DATE': 1.0,
#    'WORK_OF_ART': 0.1886792452830181,
#    'FAC': 0.2452830188679236,
#    'NORP': 0.6037735849056581,
#    'LAW': 0.018867924528301817}},
#  'what type of training': {'norm_ner': {'DATE': 1.0,
#    'QUANTITY': 0.047619047619047616}},
#  'what type of treatment': {'norm_ner': {'DATE': 1.0}},
#  'how cold before hypothermia': {'norm_ner': {'TIME': 1.0,
#    'DATE': 0.7777777777777777,
#    'QUANTITY': 1.0,
#    'ORG': 0.6666666666666665,
#    'PERSON': 0.1111111111111111,
#    'ORDINAL': 0.1111111111111111}},
#  'what type of volcano': {'norm_ner': {'ORG': 0.9999999999999974,
#    'QUANTITY': 0.5000000000000007,
#    'CARDINAL': 1.0}},
#  'what type of warrants': {'norm_ner': {'CARDINAL': 1.0,
#    'ORDINAL': 0.3333333333333335}},
#  'what type of wave': {'norm_ner': {'NORP': 1.0,
#    'DATE': 0.916666666666666,
#    'ORG': 0.41666666666666646,
#    'FAC': 0.08333333333333334,
#    'LAW': 0.08333333333333334}},
#  'what type of waves': {'norm_ner': {'CARDINAL': 0.1538461538461536,
#    'GPE': 0.26923076923076916,
#    'ORG': 0.538461538461538,
#    'ORDINAL': 0.03846153846153846,
#    'PERSON': 1.0,
#    'LAW': 0.03846153846153846,
#    'FAC': 0.03846153846153846}},
#  'what type of weather': {'norm_ner': {'ORG': 0.0769230769230765,
#    'TIME': 0.07692307692307691,
#    'DATE': 1.0,
#    'PERSON': 0.23076923076923064,
#    'ORDINAL': 0.7692307692307693,
#    'NORP': 0.6923076923076923,
#    'QUANTITY': 0.46153846153846145,
#    'FAC': 0.6923076923076923,
#    'LAW': 0.6923076923076923,
#    'EVENT': 0.07692307692307691}},
#  'what type of wild cats': {'norm_ner': {'GPE': 0.12499999999999965,
#    'ORG': 1.0,
#    'DATE': 0.3124999999999999,
#    'WORK_OF_ART': 0.0625,
#    'ORDINAL': 0.0625,
#    'FAC': 0.0625}},
#  'what type of work': {'norm_ner': {'ORG': 1.0,
#    'ORDINAL': 0.16666666666666674,
#    'FAC': 0.16666666666666674,
#    'LANGUAGE': 0.16666666666666674}},
#  'what types of actions': {'norm_ner': {'GPE': 1.0, 'PRODUCT': 1.0}},
#  'what types of animals': {'norm_ner': {'PERCENT': 1.0,
#    'LOC': 0.5000000000000001,
#    'PERSON': 0.5952380952380952,
#    'ORDINAL': 0.2142857142857143}},
#  'what types of dogs': {'norm_ner': {'ORG': 0.6666666666666665,
#    'PERSON': 1.0,
#    'TIME': 0.16666666666666669}},
#  'what types of organisms': {'norm_ner': {'GPE': 0.3999999999999998,
#    'ORG': 0.533333333333333,
#    'DATE': 1.0,
#    'QUANTITY': 0.06666666666666667}},
#  'what types of payment': {'norm_ner': {'EVENT': 0.11111111111111126,
#    'PERSON': 0.6666666666666674,
#    'ORG': 1.0,
#    'NORP': 0.11111111111111126,
#    'PRODUCT': 0.11111111111111126}},
#  'what types of plants': {'norm_ner': {'LOC': 0.1111111111111105,
#    'GPE': 0.7777777777777777,
#    'DATE': 1.0,
#    'MONEY': 0.1111111111111111}},
#  'what types of probation': {'norm_ner': {'DATE': 1.0}},
#  'what types of rocks': {'norm_ner': {'LOC': 0.12499999999999996,
#    'PERCENT': 1.0,
#    'PRODUCT': 0.59375,
#    'ORDINAL': 0.03125}},
#  'what types of trees': {'norm_ner': {'CARDINAL': 0.5844155844155844,
#    'GPE': 0.1428571428571427,
#    'MONEY': 0.09090909090909086,
#    'FAC': 0.20779220779220767,
#    'LOC': 0.35064935064935043,
#    'PERSON': 1.0,
#    'NORP': 0.5714285714285712,
#    'PERCENT': 0.10389610389610383,
#    'QUANTITY': 0.10389610389610383,
#    'WORK_OF_ART': 0.11688311688311681}},
#  'what types of triangles': {'norm_ner': {'CARDINAL': 1.0,
#    'WORK_OF_ART': 0.039999999999999994,
#    'ORG': 0.2799999999999999,
#    'FAC': 0.039999999999999994,
#    'LANGUAGE': 0.039999999999999994}},
#  'what types of vegetables': {'norm_ner': {'QUANTITY': 1.0,
#    'ORG': 1.0,
#    'ORDINAL': 1.0}},
#  'what types of walls': {'norm_ner': {'GPE': 1.0,
#    'PRODUCT': 1.0,
#    'DATE': 1.0}},
#  'what unit': {'norm_ner': {'NORP': 0.39285714285714085,
#    'GPE': 1.0,
#    'PRODUCT': 0.6071428571428544,
#    'PERCENT': 0.24999999999999886,
#    'LAW': 0.32142857142857,
#    'LOC': 0.21428571428571327,
#    'FAC': 0.10714285714285661,
#    'EVENT': 0.03571428571428555}},
#  'what units': {'norm_ner': {'PERSON': 0.4150943396226415,
#    'ORG': 1.0,
#    'CARDINAL': 0.8679245283018875,
#    'DATE': 0.509433962264151,
#    'PRODUCT': 0.30188679245283023,
#    'FAC': 0.13207547169811323,
#    'TIME': 0.01886792452830189,
#    'ORDINAL': 0.18867924528301888}},
#  'what university': {'norm_ner': {'PERSON': 1.0,
#    'NORP': 0.34210526315789463,
#    'MONEY': 0.15789473684210525,
#    'GPE': 0.5789473684210523,
#    'WORK_OF_ART': 0.1842105263157895,
#    'LOC': 0.15789473684210525,
#    'FAC': 0.3947368421052632}},
#  'what usama means': {'norm_ner': {'ORG': 0.1428571428571425,
#    'NORP': 0.6428571428571429,
#    'CARDINAL': 1.0,
#    'PERCENT': 0.07142857142857144}},
#  'what uses': {'norm_ner': {'ORDINAL': 0.6666666666666665,
#    'GPE': 0.6666666666666663,
#    'NORP': 0.7777777777777777,
#    'LANGUAGE': 0.1111111111111111,
#    'LAW': 1.0}},
#  'what uses real time os': {'norm_ner': {'ORG': 1.0,
#    'PERSON': 0.24999999999999992,
#    'FAC': 0.0625,
#    'TIME': 0.0625}},
#  'what vaccines': {'norm_ner': {'DATE': 0.8536585365853655,
#    'CARDINAL': 0.7073170731707341,
#    'GPE': 1.0,
#    'NORP': 0.024390243902439015,
#    'ORDINAL': 0.02439024390243899,
#    'PRODUCT': 0.24390243902439018,
#    'FAC': 0.024390243902439015,
#    'LOC': 0.24390243902439018,
#    'TIME': 0.024390243902439015}},
#  'what value': {'norm_ner': {'DATE': 0.20689655172413787,
#    'GPE': 1.0,
#    'NORP': 0.34482758620689646,
#    'PERSON': 0.6896551724137929,
#    'LOC': 0.034482758620689655,
#    'PRODUCT': 0.034482758620689655,
#    'QUANTITY': 0.10344827586206894,
#    'TIME': 0.034482758620689655}},
#  'what values': {'norm_ner': {'ORG': 0.33333333333333337,
#    'DATE': 0.6333333333333362,
#    'PERCENT': 0.03333333333333333,
#    'CARDINAL': 0.7333333333333333,
#    'FAC': 0.30000000000000004,
#    'PRODUCT': 0.03333333333333333,
#    'NORP': 1.0,
#    'LOC': 0.03333333333333333}},
#  'what vegetables': {'norm_ner': {'ORG': 0.4827586206896542,
#    'GPE': 0.24137931034482726,
#    'DATE': 0.5862068965517239,
#    'TIME': 0.2068965517241376,
#    'FAC': 0.5172413793103448,
#    'PERSON': 0.8275862068965513,
#    'NORP': 0.13793103448275848,
#    'CARDINAL': 0.13793103448275912,
#    'LOC': 1.0,
#    'WORK_OF_ART': 0.034482758620689655}},
#  'what vegetables to plant in february in florida': {'norm_ner': {'DATE': 1.0,
#    'ORG': 0.05882352941176463,
#    'PERSON': 0.2941176470588235,
#    'TIME': 0.05882352941176472,
#    'LAW': 0.05882352941176472,
#    'LOC': 0.05882352941176472}},
#  'what vehicle': {'norm_ner': {'DATE': 0.11999999999999986,
#    'EVENT': 0.04,
#    'NORP': 0.32,
#    'PRODUCT': 1.0,
#    'MONEY': 0.2,
#    'PERCENT': 0.04,
#    'TIME': 0.04}},
#  'what vein': {'norm_ner': {'LAW': 1.0,
#    'ORDINAL': 1.0,
#    'PERCENT': 1.0,
#    'MONEY': 1.0}},
#  'what vitamin': {'norm_ner': {'GPE': 1.0,
#    'ORG': 0.32432432432432884,
#    'PRODUCT': 0.24324324324324254,
#    'QUANTITY': 0.0405405405405404,
#    'EVENT': 0.0675675675675673}},
#  'what vitamins': {'norm_ner': {'PERSON': 0.765517241379313,
#    'GPE': 1.0,
#    'WORK_OF_ART': 0.006896551724137892,
#    'FAC': 0.21379310344827493,
#    'LOC': 0.062068965517241066,
#    'PRODUCT': 0.11034482758620641,
#    'QUANTITY': 0.006896551724137768,
#    'LAW': 0.0827586206896548,
#    'EVENT': 0.04827586206896531}},
#  'what vitamins in stinging nettle': {'norm_ner': {'ORG': 0.39999999999999974,
#    'CARDINAL': 1.0,
#    'DATE': 0.4666666666666667}},
#  'what wages': {'norm_ner': {'PERSON': 1.0,
#    'GPE': 0.43749999999999994,
#    'DATE': 0.43749999999999994,
#    'LAW': 0.0625,
#    'NORP': 0.0625}},
#  'what war': {'norm_ner': {'PERSON': 0.6991150442477881,
#    'ORG': 0.3716814159292026,
#    'DATE': 0.9557522123893804,
#    'ORDINAL': 0.10619469026548646,
#    'EVENT': 0.539823008849557,
#    'MONEY': 0.04424778761061939,
#    'CARDINAL': 0.6283185840707964,
#    'GPE': 1.0,
#    'LOC': 0.15044247787610585,
#    'WORK_OF_ART': 0.0796460176991149,
#    'PERCENT': 0.1592920353982298}},
#  'how deep': {'norm_ner': {'DATE': 0.41666666666666646,
#    'QUANTITY': 1.0,
#    'ORDINAL': 0.057017543859648905,
#    'CARDINAL': 0.5701754385964898,
#    'PERSON': 0.06578947368421019,
#    'ORG': 0.17105263157894723,
#    'PERCENT': 0.23245614035087686,
#    'TIME': 0.20175438596491163,
#    'NORP': 0.061403508771929606,
#    'FAC': 0.013157894736842047,
#    'GPE': 0.004385964912280558,
#    'MONEY': 0.3201754385964901}},
#  'what waste': {'norm_ner': {'ORG': 1.0,
#    'CARDINAL': 0.3928571428571429,
#    'PERSON': 0.6666666666666666,
#    'DATE': 0.4404761904761903,
#    'GPE': 0.21428571428571422,
#    'NORP': 0.10714285714285711,
#    'FAC': 0.0119047619047619}},
#  'what water': {'norm_ner': {'CARDINAL': 0.8615384615384626,
#    'ORG': 0.2461538461538461,
#    'EVENT': 0.015384615384615385,
#    'NORP': 0.1076923076923076,
#    'GPE': 1.0,
#    'MONEY': 0.13846153846153847,
#    'WORK_OF_ART': 0.015384615384615385,
#    'FAC': 0.015384615384615385,
#    'LAW': 0.015384615384615385,
#    'LANGUAGE': 0.07692307692307694}},
#  'what waves': {'norm_ner': {'PERSON': 0.3636363636363636,
#    'ORG': 1.0,
#    'DATE': 0.27272727272727265,
#    'MONEY': 0.09090909090909093,
#    'WORK_OF_ART': 0.09090909090909093}},
#  'what way': {'norm_ner': {'CARDINAL': 0.3181818181818178,
#    'PERSON': 1.0,
#    'MONEY': 0.4090909090909092,
#    'ORDINAL': 0.04545454545454546,
#    'TIME': 0.04545454545454546,
#    'NORP': 0.04545454545454528,
#    'PRODUCT': 0.1363636363636364,
#    'LOC': 0.3181818181818183,
#    'LANGUAGE': 0.04545454545454546,
#    'PERCENT': 0.04545454545454546,
#    'EVENT': 0.04545454545454546}},
#  'what weather': {'norm_ner': {'CARDINAL': 1.0,
#    'QUANTITY': 0.14285714285714285,
#    'TIME': 0.14285714285714285,
#    'GPE': 0.14285714285714285,
#    'LOC': 0.14285714285714285}},
#  'what what is a synthesis essay': {'norm_ner': {'PERSON': 1.0,
#    'PRODUCT': 0.07692307692307693,
#    'NORP': 0.07692307692307693,
#    'ORG': 0.07692307692307693}},
#  ...}
